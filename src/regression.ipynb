# %%
from pprint import pprint
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import itertools
import seaborn as sns

# Import the data
nyc_registry = pd.read_csv('../dogdata/NYC_Dog_Licensing_Dataset_2016-edit.csv')
coren = pd.read_csv('../dogdata/coren-edit.csv')
nyc_census = pd.read_csv('../censusdata/ACS_16_1YR_S0201_with_ann-edit.csv') # use 2016 data
edmonton_registry = pd.read_csv('../dogdata/Edmonton_Pet_Licenses_by_Neighbourhood_2018-edit.csv')
adelaide_registry = pd.read_csv('../dogdata/Dog_Registrations_Adelaide_2016-edit.csv')
wiki = pd.read_csv('../dogdata/wiki-edit.csv')
turcsan = pd.read_csv('../dogdata/turcsan.csv')

# %%
nyc_registry.corr()
# Out:
#                          RowNumber   ZipCode  CommunityDistrict  \
# RowNumber                 1.000000  0.015412           0.014468
# ZipCode                   0.015412  1.000000           0.675116
# CommunityDistrict         0.014468  0.675116           1.000000
# CensusTract2010          -0.025833  0.190871           0.226028
# CityCouncilDistrict       0.000451  0.623771           0.848630
# CongressionalDistrict     0.001321 -0.544788          -0.367818
# StateSenatorialDistrict  -0.003430 -0.777687          -0.688841
#
#                          CensusTract2010  CityCouncilDistrict  \
# RowNumber                      -0.025833             0.000451
# ZipCode                         0.190871             0.623771
# CommunityDistrict               0.226028             0.848630
# CensusTract2010                 1.000000             0.111898
# CityCouncilDistrict             0.111898             1.000000
# CongressionalDistrict          -0.265172            -0.319942
# StateSenatorialDistrict        -0.231578            -0.464006
#
#                          CongressionalDistrict  StateSenatorialDistrict
# RowNumber                             0.001321                -0.003430
# ZipCode                              -0.544788                -0.777687
# CommunityDistrict                    -0.367818                -0.688841
# CensusTract2010                      -0.265172                -0.231578
# CityCouncilDistrict                  -0.319942                -0.464006
# CongressionalDistrict                 1.000000                 0.606643
# StateSenatorialDistrict               0.606643                 1.000000
