# %% [markdown]
# ## Canine attributes study
# Michael Suttles

# %%
from pprint import pprint
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import itertools
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

import warnings
warnings.filterwarnings('ignore')

pd.options.display.max_rows = 200

# %% [markdown]
# ## Code: import the data

# %%
nyc_registry = pd.read_csv('../dogdata/NYC_Dog_Licensing_Dataset_2015-edit.csv')
coren = pd.read_csv('../dogdata/coren-edit.csv')
# nyc_census = pd.read_csv('../censusdata/ACS_16_1YR_S0201_with_ann-edit.csv') # use 2016 data
edmonton_registry = pd.read_csv('../dogdata/Edmonton_Pet_Licenses_by_Neighbourhood_2018-edit.csv')
adelaide_registry = pd.read_csv('../dogdata/Dog_Registrations_Adelaide_2016-edit.csv')
seattle_registry = pd.read_csv('../dogdata/Seattle_Pet_Licenses-2018-edit2.csv')
wiki = pd.read_csv('../dogdata/wiki-edit.csv')
turcsan = pd.read_csv('../dogdata/turcsan.csv')

# List of attributes
lst = ['Trainable', 'Obedient', 'Bold', 'Calm','Sociable']
# lst = ['Trainable', 'Bold', 'Calm','Sociable']
borough = ['Bronx','Brooklyn','Manhattan','Queens','Staten Island']
# Pare down the Coren data
coren = coren[['Breed', 'Obedient']]
# Combine the Coren and Turcsan datasets
attrib = coren.set_index('Breed').join(turcsan.set_index('Breed'), how='outer')

# %%
adelaide_registry.replace(to_replace='Labrador',value='Labrador Retriever', inplace=True)

# %% [markdown]
# ## Code: functions to display and manage data

# %%
def describe(df, categ, filename=None, display=True):
    """Show the mean and standard deviation of the data and optionally plot. Optionally save a file of the plot.
    
    Arguments:
        df {DataFrame} -- DataFrame to describe
        categ {str} -- Display category
    
    Keyword Arguments:
        filename {str} -- Name of file to save to (default: {None})
        display {bool} -- Whether or not to display a plot (default: {True})
    """
    print('\n'+categ+' Mean')
    attrib_mean = df[lst].mean()
    print(attrib_mean.round(decimals=2))
    print('\n'+categ+' Standard Deviation')
    print(attrib[lst].std().round(decimals=2))

    plt.title(categ+' Overall Attributes')
    plt.bar(attrib_mean.index, attrib_mean.values)
    plt.ylim([0,0.75])
#     fig= plt.figure(figsize=(10,6))
    if filename is not None:
        plt.savefig('../plots/'+filename)
    if display:
        plt.show()

def describe_breeds(save=False):
    '''Show the intersection of different breeds of dogs according to which dataset they come from. For example, Dogue de Bordeaux is in the Turcsan set but not in the Wiki scraped set.

    Returns:
        None
    '''
    wiki_breeds = set(wiki['Breed'].tolist())
    coren_breeds = set(coren['Breed'].tolist())
    turcsan_breeds = set(turcsan['Breed'].tolist())

    print('\nIntersection, Wiki and Turcsan')
    print(wiki_breeds & turcsan_breeds)
    print('\nIntersection, Wiki and Coren')
    print(wiki_breeds & coren_breeds)
    print('\nDifference, Wiki - Turcsan')
    print(wiki_breeds - turcsan_breeds)
    print('\nDifference, Turcsan - Wiki')
    print(turcsan_breeds - wiki_breeds)
    print('\nDifference, Wiki - Coren')
    print(wiki_breeds - coren_breeds)
    print('\nDifference, Coren - Wiki')
    print(coren_breeds - wiki_breeds)

def plot_by_attrib(df, categ,label, filename=None, display=True):
    """Plot a graph by the attributes provided.
    
    Arguments:
        df {DataFrame} -- DF to plot
        categ {list} -- Categories to plot
        label {str} -- Label for what the data is describing
    
    Keyword Arguments:
        filename {str} -- Name of the file to optionally save (default: {None})
        display {bool} -- Whether or not to display the plot (default: {True})
    """
    fig, ax = plt.subplots()
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor')
    for item in categ:
        ax.plot(df.index, df[item])

    plt.gcf().subplots_adjust(bottom=0.3, right=.75)
    plt.legend(loc=(1.04,0.6))
    plt.title('Scores by '+ label)
    ax.set_ylabel('Score')
    ax.set_xlabel(label)
    if filename is not None:
        plt.savefig('../plots/'+filename)
    if display:
        plt.show()


def splitDataFrameList(df,target_column,separator):
    """Thanks to James Allen, https://gist.github.com/jlln/338b4b0b55bd6984f883
    
    Arguments:
        df {DataFrame} -- DataFrame to split,
        target_column {string} -- The column containing the values to split
        separator {str} -- The symbol used to perform the split
    
    Returns:
        DataFrame -- A dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    """
    def splitListToRows(row,row_accumulator,target_column,separator):
        split_row = row[target_column].split(separator)
        for s in split_row:
            new_row = row.to_dict()
            new_row[target_column] = s
            row_accumulator.append(new_row)
    new_rows = []
    df.apply(splitListToRows,axis=1,args = (new_rows,target_column,separator))
    new_df = pd.DataFrame(new_rows)
    return new_df

# %% [markdown]
# ## Summary statistics

# %%
print('Note: for a 1-year period varying from 2015-2018')
print('New York total dogs: ',nyc_registry.shape[0])
print('Seattle total dogs:  ',seattle_registry.shape[0])
print('Edmonton total dogs: ',edmonton_registry.shape[0])
print('Adelaide total dogs: ',adelaide_registry.shape[0])
# Out:
# Note: for a 1-year period varying from 2015-2018
# New York total dogs:  121950
# Seattle total dogs:   18227
# Edmonton total dogs:  59266
# Adelaide total dogs:  16075

# %% [markdown]
# There is something wrong with the Seattle dataset. For example, in 2015 there were only approx 206 dogs registered.

# %% [markdown]
# ## Dog ownership by population

# %%
ny_pop = 8582000
seattle_pop = 3870000
edmonton_pop = 966000
adelaide_pop = 1340000

print('New York ownership/reporting percentage: ',round(100*nyc_registry.shape[0]/ny_pop,3))
print('Seattle ownership/reporting percentage: ',round(100*seattle_registry.shape[0]/seattle_pop,3))
print('Edmonton ownership/reporting percentage: ',round(100*edmonton_registry.shape[0]/edmonton_pop,3))
print('Adelaide ownership/reporting percentage: ',round(100*adelaide_registry.shape[0]/adelaide_pop,3))
# Out:
# New York ownership/reporting percentage:  1.421
# Seattle ownership/reporting percentage:  0.471
# Edmonton ownership/reporting percentage:  6.135
# Adelaide ownership/reporting percentage:  1.2

# %% [markdown]
# The widely varying percentages imply there may be a problem with some of the data--especially in Seattle, as noted above. Edmonton has an abnormally high percentage.

# %% [markdown]
# ## Correlation coefficients among attributes

# %%
attrib.corr()
# Out:
#            Obedient      Calm  Trainable  Sociable      Bold
# Obedient   1.000000 -0.224701   0.363011 -0.187287 -0.200141
# Calm      -0.224701  1.000000  -0.596697  0.864370  0.753806
# Trainable  0.363011 -0.596697   1.000000 -0.331093 -0.409075
# Sociable  -0.187287  0.864370  -0.331093  1.000000  0.815936
# Bold      -0.200141  0.753806  -0.409075  0.815936  1.000000

# %% [markdown]
# ## Show which dogs are in each dataset

# %%
describe_breeds()
# Out:
# Intersection, Wiki and Turcsan
# {'Dachshund', 'Dalmatian', 'Rottweiler', 'Pekingese', 'Great Dane', 'Chihuahua', 'Jack Russell Terrier', 'Irish Terrier', 'Whippet', 'Welsh Terrier', 'Shiba Inu', 'American Staffordshire Terrier', 'Beauceron', 'Shetland Sheepdog', 'Belgian Malinois', 'Vizsla', 'Weimaraner', 'Bearded Collie', 'Poodle', 'Cavalier King Charles Spaniel', 'Siberian Husky', 'Gordon Setter', 'Doberman Pinscher', 'Shih Tzu', 'Bulldog', 'German Wirehaired Pointer', 'Maltese', 'Lhasa Apso', 'German Shorthaired Pointer', 'Golden Retriever', 'German Shepherd', 'Irish Setter', 'Miniature Poodle', 'Old English Sheepdog', 'Tibetan Terrier', 'Border Collie', 'Border Terrier', 'Staffordshire Bull Terrier', 'Standard Schnauzer', 'Giant Schnauzer', 'French Bulldog', 'Brittany', 'Ibizan Hound', 'Soft-Coated Wheaten Terrier', 'Rhodesian Ridgeback', 'Australian Shepherd', 'English Setter', 'Yorkshire Terrier', 'Greater Swiss Mountain Dog', 'Beagle', 'Polish Lowland Sheepdog', 'Pointer', 'Briard', 'Bull Terrier', 'Saint Bernard', 'Airedale Terrier', 'Pug', 'Shar Pei', 'Irish Wolfhound', 'Labrador Retriever', 'Coton de Tulear', 'Flat-Coated Retriever', 'Alaskan Malamute', 'Cairn Terrier', 'Boxer', 'Bernese Mountain Dog'}
#
# Intersection, Wiki and Coren
# {'Cocker Spaniel', 'Rottweiler', 'Welsh Springer Spaniel', 'Great Dane', 'Jack Russell Terrier', 'Whippet', 'Welsh Terrier', 'Saluki', 'Bloodhound', 'Vizsla', 'Sealyham Terrier', 'Greyhound', 'Bearded Collie', 'Akita', 'Irish Water Spaniel', 'Bulldog', 'Bichon Frise', 'Portuguese Water Dog', 'Norwegian Elkhound', 'Ibizan Hound', 'Chinese Crested', 'Australian Shepherd', 'English Springer Spaniel', 'Skye Terrier', 'Beagle', 'Pharaoh Hound', 'Briard', 'Airedale Terrier', 'Shar Pei', 'Irish Wolfhound', 'Dalmatian', 'Wirehaired Pointing Griffon', 'Bedlington Terrier', 'Irish Terrier', 'American Staffordshire Terrier', 'Australian Terrier', 'Weimaraner', 'Poodle', 'Belgian Sheepdog', 'Tibetan Spaniel', 'American Foxhound', 'Lhasa Apso', 'Golden Retriever', 'Irish Setter', 'English Foxhound', 'Old English Sheepdog', 'Finnish Spitz', 'Australian Cattle Dog', 'Otter Hound', 'Soft-Coated Wheaten Terrier', 'Bouvier des Flandres', 'Chesapeake Bay Retriever', 'Pointer', 'Bull Terrier', 'Labrador Retriever', 'Alaskan Malamute', 'West Highland White Terrier', 'Cairn Terrier', 'Bullmastiff', 'Curly Coated Retriever', 'Fox Terrier', 'Dachshund', 'Petit Basset Griffon Vendeen', 'Newfoundland', 'Clumber Spaniel', 'Belgian Malinois', 'Cardigan Welsh Corgi', 'Black and Tan Coonhound', 'Basenji', 'Bernese Mountain Dog', 'Field Spaniel', 'Doberman Pinscher', 'German Wirehaired Pointer', 'Maltese', 'Puli', 'German Shorthaired Pointer', 'Border Terrier', 'Giant Schnauzer', 'Brittany', 'American Water Spaniel', 'Yorkshire Terrier', 'Japanese Chin', 'Great Pyrenees', 'Boston Terrier', 'Saint Bernard', 'Brussels Griffon', 'Pug', 'Kuvasz', 'Lakeland Terrier', 'Basset Hound', 'Flat-Coated Retriever', 'Afghan Hound', 'Boxer', 'Pekingese', 'Manchester Terrier', 'Chihuahua', 'Shiba Inu', 'Scottish Deerhound', 'Dandie Dinmont Terrier', 'Chow Chow', 'Affenpinscher', 'Shetland Sheepdog', 'Cavalier King Charles Spaniel', 'Siberian Husky', 'Gordon Setter', 'Shih Tzu', 'Schipperke', 'German Shepherd', 'Tibetan Terrier', 'Border Collie', 'Staffordshire Bull Terrier', 'Standard Schnauzer', 'Kerry Blue Terrier', 'Italian Greyhound', 'French Bulldog', 'Scottish Terrier', 'Rhodesian Ridgeback', 'English Setter', 'Pomeranian', 'Borzoi', 'Keeshond'}
#
# Difference, Wiki - Turcsan
# {'Cocker Spaniel', 'Welsh Springer Spaniel', 'Saluki', 'Bloodhound', 'Sealyham Terrier', 'Greyhound', 'Redbone Coonhound', 'Akita', 'Irish Water Spaniel', 'American Eskimo', 'Bichon Frise', 'Portuguese Water Dog', 'Tibetan Mastiff', 'Norwegian Elkhound', 'Chinese Crested', 'English Springer Spaniel', 'Canaan Dog', 'Skye Terrier', 'Pharaoh Hound', 'Plott Hound', 'Fox Terrier Smooth', 'Wirehaired Pointing Griffon', 'Bedlington Terrier', 'Australian Terrier', 'Belgian Sheepdog', 'Tibetan Spaniel', 'American Foxhound', 'English Foxhound', 'Finnish Spitz', 'Australian Cattle Dog', 'Otter Hound', 'Bouvier des Flandres', 'Chesapeake Bay Retriever', 'Spinone Italiano', 'West Highland White Terrier', 'Bullmastiff', 'Curly Coated Retriever', 'Komondor', 'Petit Basset Griffon Vendeen', 'Fox Terrier', 'Newfoundland', 'Clumber Spaniel', 'Black and Tan Coonhound', 'Cardigan Welsh Corgi', 'Basenji', 'Field Spaniel', 'Silky Terrier', 'Toy Fox Terrier', 'Puli', 'American Water Spaniel', 'Sussex Spaniel', 'Japanese Chin', 'Great Pyrenees', 'Boston Terrier', 'Brussels Griffon', 'Lakeland Terrier', 'Kuvasz', 'Basset Hound', 'Afghan Hound', 'English Toy Spaniel', 'Manchester Terrier', 'Scottish Deerhound', 'Chow Chow', 'Dandie Dinmont Terrier', 'Affenpinscher', 'Schipperke', 'German Pinscher', 'Belgian Tervuren', 'Kerry Blue Terrier', 'Scottish Terrier', 'Italian Greyhound', 'Nova Scotia Duck Tolling Retriever', 'Pomeranian', 'Toy Poodle', 'Black Russian Terrier', 'Borzoi', 'Keeshond'}
#
# Difference, Turcsan - Wiki
# {'Pyrenean Shepherd', 'Anatolian Shepherd Dog', 'English Cocker Spaniel', 'White Swiss Shepherd', 'Hovawart', 'American Cocker Spaniel', 'Havanese', 'Wirehaired Dachshund', 'Dogue de Bordeaux', 'Wolfspitz', 'German Hunting Terrier', 'Appenzeller Sennenhund', 'Eurasier', 'German Spitz', 'Small Munsterlander', 'Miniature Pinscher', 'Perro de Presa Canario', 'Bavarian Mountain Hound', 'Kromfohrlander', 'Parson Russell Terrier', 'Miniature Dachshund', 'Collie', 'Leonberger', 'Miniature Schnauzer', 'Entlebucher Mountain Dog', 'West Highland Wheaten Terrier'}
#
# Difference, Wiki - Coren
# {'English Toy Spaniel', 'Komondor', 'Fox Terrier Smooth', 'Beauceron', 'Redbone Coonhound', 'Silky Terrier', 'Toy Fox Terrier', 'American Eskimo', 'German Pinscher', 'Tibetan Mastiff', 'Miniature Poodle', 'Belgian Tervuren', 'Sussex Spaniel', 'Greater Swiss Mountain Dog', 'Nova Scotia Duck Tolling Retriever', 'Canaan Dog', 'Polish Lowland Sheepdog', 'Spinone Italiano', 'Toy Poodle', 'Coton de Tulear', 'Plott Hound', 'Black Russian Terrier'}
#
# Difference, Coren - Wiki
# {'Pembroke Welsh Corgi', 'Belgian Shepherd', 'King Charles Spaniel', 'Norwich Terrier', 'Wire Fox Terrier', 'Norfolk Terrier', 'Papillon', 'Collie', 'Havanese', 'Mastiff', 'English Cocker Spaniel', 'Miniature Schnauzer', 'Samoyed', 'Australian Silky Terrier', 'Miniature Pinscher'}

# %% [markdown]
# # Attributes by AKC groupings
# Similar to what Turcsán did in her paper

# %%
wiki_akc = wiki[['Breed', 'AKC']]
akc_groups_attrib = wiki_akc.set_index('Breed').join(attrib, how='left')
print('\nAKC Mean')
akc = akc_groups_attrib.groupby('AKC').mean().round(decimals=2)
pprint(akc)
print('\nAKC Standard Deviation')
akc_std = akc_groups_attrib.groupby('AKC').std().round(decimals=2)
pprint(akc_std)
print('\nAKC Count')
akc_count = akc_groups_attrib.groupby('AKC').count()
pprint(akc_count)

# Plot the AKC grouping data
plot_by_attrib(akc, lst, 'AKC Grouping')
# Out:
# AKC Mean
#               Obedient  Calm  Trainable  Sociable  Bold
# AKC
# Herding           0.77  0.30       0.85      0.45  0.30
# Hound             0.44  0.50       0.67      0.58  0.33
# Non-Sporting      0.53  0.44       0.67      0.44  0.22
# Sporting          0.73  0.67       0.62      0.67  0.62
# Terrier           0.51  0.30       0.75      0.30  0.35
# Toy               0.42  0.62       0.25      0.56  0.69
# Working           0.60  0.45       0.73      0.41  0.36
#
# AKC Standard Deviation
#               Obedient  Calm  Trainable  Sociable  Bold
# AKC
# Herding           0.20  0.48       0.24      0.44  0.48
# Hound             0.14  0.55       0.41      0.38  0.52
# Non-Sporting      0.23  0.53       0.43      0.39  0.44
# Sporting          0.15  0.49       0.38      0.44  0.48
# Terrier           0.17  0.48       0.35      0.48  0.47
# Toy               0.21  0.52       0.27      0.50  0.37
# Working           0.22  0.52       0.34      0.49  0.50
#
# AKC Count
#               Obedient  Calm  Trainable  Sociable  Bold
# AKC
# Herding             13    10         10        10    10
# Hound               21     6          6         6     6
# Non-Sporting        14     9          9         9     9
# Sporting            22    12         12        12    12
# Terrier             20    10         10        10    10
# Toy                 15     8          8         8     8
# Working             16    11         11        11    11

# %% [markdown]
# ## Display breed attributes by NYC borough

# %%
# Strip out NYC dirty values
nyc_registry['Borough'] = nyc_registry['Borough'].map(lambda x: None if x not in {'Brooklyn', 'Bronx', 'Staten Island', 'Manhattan', 'Queens'} else x)
nyc_registry.replace(to_replace='Unknown',value=np.nan, inplace=True)
nyc_registry.replace(to_replace='American Pit Bull Mix / Pit Bull Mix',value='Pit Bull Mix', inplace=True)
nyc_registry.replace(to_replace='American Pit Bull Terrier/Pit Bull',value='American Staffordshire Terrier', inplace=True)
nyc_registry.dropna(inplace=True)

display = True # Display the graph
norm=False # Whether or not to normalize
nyc_attrib = nyc_registry.set_index('BreedName').join(attrib, how='left')
nyc_attrib = nyc_attrib[['Borough','Calm', 'Trainable', 'Sociable', 'Bold', 'Obedient']]
# nyc_attrib = nyc_attrib[['Borough','Calm', 'Trainable', 'Sociable', 'Bold']]
nyc_attrib_g = nyc_attrib.groupby('Borough')
print('\nNYC Mean:')
nyc_attrib_g_mean = nyc_attrib_g.mean()
pprint(nyc_attrib_g_mean.round(decimals=2))
print('\nNYC Standard Deviation:')
pprint(nyc_attrib_g.std().round(decimals=2))
print('\nNYC Count:')
pprint(nyc_attrib_g.count())
if display:
    plot_by_attrib(nyc_attrib_g_mean, lst, 'NYC Borough')

nyc_breeds = nyc_registry[['Borough', 'BreedName']]
print('\nTop NYC Dogs Count')
pprint(nyc_breeds['BreedName'].value_counts().nlargest(12))
nyc_breeds_grp = nyc_breeds.groupby('Borough')
print('\nTop Dogs By Borough')
for b in borough:
    print('\n'+b)
    print(nyc_breeds_grp.get_group(b)['BreedName'].value_counts(normalize=norm).head(12))
# Out:
# NYC Mean:
#                Calm  Trainable  Sociable  Bold  Obedient
# Borough
# Bronx          0.36       0.42      0.36  0.54      0.52
# Brooklyn       0.42       0.47      0.43  0.56      0.54
# Manhattan      0.49       0.49      0.50  0.61      0.55
# Queens         0.44       0.45      0.44  0.58      0.54
# Staten Island  0.48       0.48      0.48  0.60      0.56
#
# NYC Standard Deviation:
#                Calm  Trainable  Sociable  Bold  Obedient
# Borough
# Bronx          0.48       0.40      0.47  0.39      0.24
# Brooklyn       0.49       0.39      0.48  0.41      0.24
# Manhattan      0.50       0.36      0.49  0.42      0.24
# Queens         0.50       0.38      0.48  0.40      0.25
# Staten Island  0.50       0.37      0.49  0.41      0.26
#
# NYC Count:
#                 Calm  Trainable  Sociable   Bold  Obedient
# Borough
# Bronx           6516       6516      6516   6516      7334
# Brooklyn       13996      13996     13996  13996     16514
# Manhattan      19680      19680     19680  19680     23569
# Queens         11741      11741     11741  11741     13800
# Staten Island   5201       5201      5201   5201      6037
# Top NYC Dogs Count
# Yorkshire Terrier                 7412
# Shih Tzu                          6835
# Chihuahua                         5555
# Maltese                           4117
# Labrador Retriever                4055
# Pit Bull Mix                      3279
# American Staffordshire Terrier    3196
# Labrador Retriever Crossbreed     2677
# Pomeranian                        2107
# Beagle                            2017
# Havanese                          1962
# Jack Russell Terrier              1962
# Name: BreedName, dtype: int64
#
# Top Dogs By Borough
#
# Bronx
# Yorkshire Terrier                 1171
# Shih Tzu                          1046
# Chihuahua                          830
# American Staffordshire Terrier     689
# Pit Bull Mix                       513
# Maltese                            510
# Labrador Retriever                 246
# Pomeranian                         241
# German Shepherd Dog                216
# Shih Tzu Crossbreed                188
# Jack Russell Terrier               180
# Labrador Retriever Crossbreed      178
# Name: BreedName, dtype: int64
#
# Brooklyn
# Yorkshire Terrier                 1923
# Shih Tzu                          1838
# Chihuahua                         1456
# Pit Bull Mix                      1033
# Labrador Retriever                 929
# Maltese                            926
# American Staffordshire Terrier     917
# Labrador Retriever Crossbreed      791
# Pomeranian                         545
# Jack Russell Terrier               530
# German Shepherd Crossbreed         492
# Beagle                             489
# Name: BreedName, dtype: int64
#
# Manhattan
# Yorkshire Terrier                2017
# Chihuahua                        1871
# Shih Tzu                         1768
# Labrador Retriever               1618
# Maltese                          1174
# Havanese                         1161
# Labrador Retriever Crossbreed     922
# Golden Retriever                  882
# Cavalier King Charles Spaniel     803
# Pit Bull Mix                      756
# Jack Russell Terrier              732
# French Bulldog                    717
# Name: BreedName, dtype: int64
#
# Queens
# Yorkshire Terrier                 1607
# Shih Tzu                          1496
# Maltese                           1129
# Chihuahua                         1057
# Labrador Retriever                 711
# American Staffordshire Terrier     697
# Pit Bull Mix                       622
# German Shepherd Dog                553
# Beagle                             529
# Labrador Retriever Crossbreed      528
# Pomeranian                         500
# Cocker Spaniel                     438
# Name: BreedName, dtype: int64
#
# Staten Island
# Yorkshire Terrier                 694
# Shih Tzu                          687
# Labrador Retriever                551
# Maltese                           378
# Pit Bull Mix                      355
# Chihuahua                         341
# American Staffordshire Terrier    308
# German Shepherd Dog               271
# Labrador Retriever Crossbreed     258
# Beagle                            227
# Boxer                             188
# Golden Retriever                  185
# Name: BreedName, dtype: int64

# %% [markdown]
# ## Perform Chi-Squared analysis on NYC data
# Are the distributions of dogs in NYC statistically significant with respect to which borough one is in? I look at the five most common breeds, pairwise.

# %%
chi2_breed = ['Yorkshire Terrier', 'Shih Tzu','Chihuahua', 'Maltese', 'Labrador Retriever']
chi2_breed_com = itertools.combinations(chi2_breed, 2)
nyc_breeds_5 = nyc_registry[nyc_registry['BreedName'].isin(chi2_breed)] #top 5 breeds overall
for i in chi2_breed_com:
    print('\n',i)
    nyc_breeds_2 = nyc_registry[nyc_registry['BreedName'].isin(i)]
    contingency_table = pd.crosstab(nyc_breeds_2['BreedName'], nyc_breeds_2['Borough'])
    nyc_chi2 = stats.chi2_contingency(contingency_table)
    print('Test statistic: {}'.format(nyc_chi2[0].round(2)))
    print('P-value: {}'.format(nyc_chi2[1]))
# Out:
#  ('Yorkshire Terrier', 'Shih Tzu')
# Test statistic: 6.0
# P-value: 0.19935815394309653
#
#  ('Yorkshire Terrier', 'Chihuahua')
# Test statistic: 98.16
# P-value: 2.429327716068869e-20
#
#  ('Yorkshire Terrier', 'Maltese')
# Test statistic: 72.38
# P-value: 7.147745625233244e-15
#
#  ('Yorkshire Terrier', 'Labrador Retriever')
# Test statistic: 409.12
# P-value: 2.980385866171689e-87
#
#  ('Shih Tzu', 'Chihuahua')
# Test statistic: 133.21
# P-value: 7.994705402523028e-28
#
#  ('Shih Tzu', 'Maltese')
# Test statistic: 76.64
# P-value: 8.981695413046296e-16
#
#  ('Shih Tzu', 'Labrador Retriever')
# Test statistic: 411.94
# P-value: 7.309724499346304e-88
#
#  ('Chihuahua', 'Maltese')
# Test statistic: 147.63
# P-value: 6.557578045686694e-31
#
#  ('Chihuahua', 'Labrador Retriever')
# Test statistic: 343.14
# P-value: 5.304888286870627e-73
#
#  ('Maltese', 'Labrador Retriever')
# Test statistic: 289.52
# P-value: 1.9691645730782012e-61

# %% [markdown]
# The distribution of *all* dog breeds in NYC based on the borough is statistially significant except for the distribution of Yorkshire Terriers vs. Shih Tzus.

# %% [markdown]
# ## Seattle dog attributes
# Seattle data includes ONLY dogs with a primary breed. Secondary breeds are excluded.

# %%
seattle_attrib = seattle_registry[pd.isnull(seattle_registry['Secondary Breed'])]
seattle_attrib = seattle_registry.set_index('Primary Breed').join(attrib, how='left')
seattle_attrib
# Out:
#                            License Issue Date License Number  \
# Affenpinscher                   April 18 2018         210596
# Affenpinscher                   March 21 2018         126404
# Afghan Hound                     July 23 2018        S119455
# Afghan Hound                      May 01 2018         141025
# Afghan Hound                     July 23 2018        S119454
# Afghan Hound                      May 31 2018         139371
# Airedale Terrier             December 13 2018         955156
# Airedale Terrier             November 06 2018         903738
# Airedale Terrier             November 14 2018         903865
# Airedale Terrier              October 31 2018        S122731
# Airedale Terrier             November 01 2018        8002383
# Airedale Terrier             December 22 2018        S138765
# Airedale Terrier             November 25 2018         831829
# Airedale Terrier             November 15 2018         901063
# Airedale Terrier              October 26 2018         829335
# Airedale Terrier             December 20 2018         960647
# Airedale Terrier             December 26 2018        8004137
# Airedale Terrier             November 26 2018         903207
# Airedale Terrier              October 27 2018        S113778
# Airedale Terrier             December 31 2018        8004256
# Airedale Terrier                March 20 2018         139797
# Airedale Terrier                 June 20 2018         142879
# Airedale Terrier               August 04 2018         581276
# Airedale Terrier             February 12 2018          80353
# Airedale Terrier                 July 31 2018        S116242
# Airedale Terrier                  May 22 2018        S128112
# Airedale Terrier               August 02 2018        S147625
# Airedale Terrier                  May 01 2018        S143363
# Airedale Terrier                April 10 2018         206213
# Airedale Terrier                April 17 2018        S142890
# Airedale Terrier            September 24 2018         355925
# Airedale Terrier                April 26 2018        S143259
# Airedale Terrier                 July 02 2018        S145513
# Airedale Terrier                  May 15 2018        S143752
# Airedale Terrier                April 19 2018        S127584
# Airedale Terrier                March 20 2018         139795
# Airedale Terrier            September 03 2018        S120963
# Airedale Terrier                 July 31 2018        S116243
# Airedale Terrier               August 25 2018        8000355
# Airedale Terrier                 July 13 2018         211845
# Airedale Terrier              October 17 2018        8001965
# Airedale Terrier              October 10 2018        S136964
# Airedale Terrier                 June 23 2018        S114871
# Airedale Terrier               August 30 2018        S115950
# Airedale Terrier              October 06 2018         831354
# Airedale Terrier              October 11 2018        S135838
# Airedale Terrier                April 13 2018        S105157
# Airedale Terrier              October 17 2018        S123677
# Airedale Terrier              October 12 2018        S137130
# Airedale Terrier                March 27 2018        S116150
# Airedale Terrier            September 05 2018        S120971
# Airedale Terrier                 July 26 2018         585247
# Airedale Terrier                 July 24 2018        S103581
# Akbash                       November 03 2018         835066
# Akbash                           June 05 2018        S144406
# Akbash                       February 20 2018        S140667
# Akita                        November 03 2018        S122687
# Akita                        December 02 2018         835072
# Akita                        November 05 2018        S124466
# Akita                        November 06 2018        S122407
# Akita                        November 05 2018        S135408
# Akita                        December 20 2018        S109090
# Akita                        November 06 2018         903832
# Akita                        December 24 2018        S152291
# Akita                         January 19 2018        S139655
# Akita                          August 29 2018        S145972
# Akita                            June 22 2018        S144364
# Akita                           April 03 2018         137235
# Akita                           April 24 2018        S111543
# Akita                            July 18 2018        S146601
# Akita                         January 06 2018        S139259
# Akita                        February 27 2018        S141040
# Akita                       September 30 2018        8001428
# Akita                       September 04 2018         726386
# Akita                           April 23 2018        S111944
# Akita                           March 29 2018         140873
# Akita                            July 31 2018        S147549
# Akita                           March 29 2018         215881
# Akita                          August 10 2018        S100452
# Akita                           March 23 2018        S127238
# Akita                       September 03 2018        S121245
# Akita                       September 24 2018        8001246
# Akita                            June 19 2018         215924
# Akita                         January 16 2018          24769
# Akita                       September 15 2018         583383
# Akita                           April 17 2018         212291
# Akita                        February 07 2018        S140407
# Akita                        February 09 2018        S111235
# Akita                            July 25 2018        S119982
# Akita                           April 03 2018         136686
# Akita                          August 14 2018        8000069
# Akita                       September 24 2018        S146685
# Akita                           April 18 2018        S128143
# Akita                           March 28 2018        S141847
# Akita                           March 20 2018         139361
# Akita                           March 20 2018         135456
# Akita                          August 08 2018        S120348
# Alapaha Blue Blood Bulldog   November 07 2018        S137136
# Alapaha Blue Blood Bulldog        May 24 2018        S141971
# Alaskan Husky                November 12 2018        S135451
# ...                                       ...            ...
# Yorkshire Terrier             January 06 2018        S139210
# Yorkshire Terrier           September 30 2018        S118582
# Yorkshire Terrier                 May 19 2018         282777
# Yorkshire Terrier                July 03 2018        S128719
# Yorkshire Terrier                July 30 2018         582967
# Yorkshire Terrier                July 24 2018         582840
# Yorkshire Terrier             October 07 2018         728103
# Yorkshire Terrier           September 23 2018         728616
# Yorkshire Terrier                July 23 2018          70905
# Yorkshire Terrier               April 23 2018        S106593
# Yorkshire Terrier                 May 01 2018        S111938
# Yorkshire Terrier              August 25 2018        S119484
# Yorkshire Terrier                June 14 2018         360327
# Yorkshire Terrier            February 09 2018          84234
# Yorkshire Terrier               March 28 2018         830856
# Yorkshire Terrier                July 24 2018        S119546
# Yorkshire Terrier               March 28 2018         140826
# Yorkshire Terrier           September 09 2018         729215
# Yorkshire Terrier            February 20 2018        S140719
# Yorkshire Terrier                 May 12 2018          81582
# Yorkshire Terrier             October 17 2018        S146735
# Yorkshire Terrier              August 24 2018        8000323
# Yorkshire Terrier           September 03 2018        8000589
# Yorkshire Terrier           September 19 2018         572642
# Yorkshire Terrier             October 10 2018        8001738
# Yorkshire Terrier               March 20 2018        S129485
# Yorkshire Terrier               April 29 2018          78373
# Yorkshire Terrier                July 01 2018         360414
# Yorkshire Terrier             October 08 2018         835363
# Yorkshire Terrier           September 07 2018         726878
# Yorkshire Terrier                July 16 2018        S118792
# Yorkshire Terrier             October 17 2018        8001939
# Yorkshire Terrier                June 12 2018         444763
# Yorkshire Terrier               April 19 2018         205168
# Yorkshire Terrier             January 25 2018        S139194
# Yorkshire Terrier               March 20 2018        S141615
# Yorkshire Terrier             October 13 2018        8001836
# Yorkshire Terrier              August 17 2018        8000159
# Yorkshire Terrier                July 05 2018          29485
# Yorkshire Terrier                July 21 2018        S119818
# Yorkshire Terrier             October 14 2018        8001847
# Yorkshire Terrier                June 14 2018        S130352
# Yorkshire Terrier               April 10 2018        S114275
# Yorkshire Terrier                July 18 2018        S146602
# Yorkshire Terrier               March 06 2018        S126186
# Yorkshire Terrier           September 04 2018         581559
# Yorkshire Terrier              August 04 2018         833915
# Yorkshire Terrier               March 13 2018         902456
# Yorkshire Terrier            February 08 2018          83009
# Yorkshire Terrier           September 07 2018         722414
# Yorkshire Terrier               April 13 2018        S113954
# Yorkshire Terrier                 May 10 2018         359965
# Yorkshire Terrier              August 17 2018        S102146
# Yorkshire Terrier               March 22 2018        S140942
# Yorkshire Terrier                July 21 2018         354786
# Yorkshire Terrier                June 27 2018        S145387
# Yorkshire Terrier            February 06 2018        S110253
# Yorkshire Terrier           September 11 2018        8000841
# Yorkshire Terrier                July 31 2018         445335
# Yorkshire Terrier                July 07 2018         435933
# Yorkshire Terrier                June 12 2018        S144613
# Yorkshire Terrier               April 11 2018        S142349
# Yorkshire Terrier              August 30 2018         357287
# Yorkshire Terrier           September 02 2018         729482
# Yorkshire Terrier               March 06 2018        S112401
# Yorkshire Terrier           September 08 2018         719965
# Yorkshire Terrier           September 30 2018        S146687
# Yorkshire Terrier              August 17 2018        8000161
# Yorkshire Terrier                June 27 2018        S112103
# Yorkshire Terrier               April 26 2018          71084
# Yorkshire Terrier                 May 15 2018          64361
# Yorkshire Terrier                July 01 2018         348621
# Yorkshire Terrier                June 19 2018        S144752
# Yorkshire Terrier            February 28 2018          15352
# Yorkshire Terrier                June 19 2018        S123925
# Yorkshire Terrier             January 30 2018        S140161
# Yorkshire Terrier                 May 22 2018        S143987
# Yorkshire Terrier                 May 08 2018         211719
# Yorkshire Terrier                June 20 2018         358057
# Yorkshire Terrier             October 11 2018        8001783
# Yorkshire Terrier               March 31 2018        S129294
# Yorkshire Terrier               April 10 2018        S142304
# Yorkshire Terrier               March 14 2018          23362
# Yorkshire Terrier                 May 16 2018        S143848
# Yorkshire Terrier             January 28 2018         961426
# Yorkshire Terrier           September 19 2018         572640
# Yorkshire Terrier           September 20 2018        8001126
# Yorkshire Terrier                July 17 2018         274171
# Yorkshire Terrier               March 20 2018         134304
# Yorkshire Terrier             January 16 2018          19548
# Yorkshire Terrier               March 23 2018        S127291
# Yorkshire Terrier                July 25 2018         439699
# Yorkshire Terrier             October 14 2018        S135874
# Yorkshire Terrier              August 03 2018        S129868
# Yorkshire Terrier            February 01 2018        S117431
# Yorkshire Terrier                June 04 2018        S115841
# Yorkshire Terrier              August 22 2018         729847
# Yorkshire Terrier           September 20 2018        S146385
# Yorkshire Terrier           September 26 2018        S134804
# Yorkshire Terrier             October 01 2018        8001462
#
#                                          Animal's Name Species  \
# Affenpinscher                                   Poirot     Dog
# Affenpinscher                                    Lucky     Dog
# Afghan Hound                                   Asteria     Dog
# Afghan Hound                                      Abby     Dog
# Afghan Hound                                     Atlas     Dog
# Afghan Hound                                      Luca     Dog
# Airedale Terrier                                  Otis     Dog
# Airedale Terrier                               Winston     Dog
# Airedale Terrier                                 Hogan     Dog
# Airedale Terrier                                 Daisy     Dog
# Airedale Terrier                                 Ellie     Dog
# Airedale Terrier                           Chimichurri     Dog
# Airedale Terrier                                 Daisy     Dog
# Airedale Terrier                                  Lucy     Dog
# Airedale Terrier                                  Nani     Dog
# Airedale Terrier                            Maddie Mae     Dog
# Airedale Terrier                                Palmer     Dog
# Airedale Terrier                                Maggie     Dog
# Airedale Terrier                                 Atlas     Dog
# Airedale Terrier                                Darwin     Dog
# Airedale Terrier                            Sophie May     Dog
# Airedale Terrier                                Oliver     Dog
# Airedale Terrier                                Harvey     Dog
# Airedale Terrier                                  Rory     Dog
# Airedale Terrier                                Bosley     Dog
# Airedale Terrier                                  Luna     Dog
# Airedale Terrier                                 Ellie     Dog
# Airedale Terrier                                   Max     Dog
# Airedale Terrier                                Nootka     Dog
# Airedale Terrier                                Violet     Dog
# Airedale Terrier                                 Darby     Dog
# Airedale Terrier                                 Wally     Dog
# Airedale Terrier                                  Dash     Dog
# Airedale Terrier                                Juneau     Dog
# Airedale Terrier                                Archer     Dog
# Airedale Terrier                                  Dave     Dog
# Airedale Terrier                                 Gizmo     Dog
# Airedale Terrier                                 Monty     Dog
# Airedale Terrier                         Charlie Brown     Dog
# Airedale Terrier                                  Tank     Dog
# Airedale Terrier                                RUPERT     Dog
# Airedale Terrier                                    Ri     Dog
# Airedale Terrier                               Wallace     Dog
# Airedale Terrier                                 Felix     Dog
# Airedale Terrier                               Chester     Dog
# Airedale Terrier                                 Ketch     Dog
# Airedale Terrier            Duchess Lacy van Notendale     Dog
# Airedale Terrier                     morgan4c27435168b     Dog
# Airedale Terrier                                Maisie     Dog
# Airedale Terrier                                 Artie     Dog
# Airedale Terrier                                Maggie     Dog
# Airedale Terrier                                Maggie     Dog
# Airedale Terrier                                  Hops     Dog
# Akbash                                           Sully     Dog
# Akbash                                            Yeti     Dog
# Akbash                                          Soappy     Dog
# Akita                                              Eva     Dog
# Akita                                           Dakota     Dog
# Akita                                             Toba     Dog
# Akita                                            Gizmo     Dog
# Akita                                             Bear     Dog
# Akita                                           Denali     Dog
# Akita                                             Sara     Dog
# Akita                                              Neo     Dog
# Akita                                            Himba     Dog
# Akita                                             Momo     Dog
# Akita                                             Desi     Dog
# Akita                                           Biggie     Dog
# Akita                                             Koda     Dog
# Akita                                      Rambo Buddy     Dog
# Akita                                               Lu     Dog
# Akita                                             Ella     Dog
# Akita                                            Sashi     Dog
# Akita                                           Wasabi     Dog
# Akita                                        Kira Kunz     Dog
# Akita                                             Abby     Dog
# Akita                                             Bear     Dog
# Akita                                             Koto     Dog
# Akita                                           Niseko     Dog
# Akita                                             Jack     Dog
# Akita                                             Kodi     Dog
# Akita                                              MAx     Dog
# Akita                                            Melba     Dog
# Akita                                      Smokey Bear     Dog
# Akita                                             Kita     Dog
# Akita                                              Aki     Dog
# Akita                                           Shinju     Dog
# Akita                                           Owsley     Dog
# Akita                                           Brodie     Dog
# Akita                                            Raven     Dog
# Akita                                               Oz     Dog
# Akita                                           Gunner     Dog
# Akita                                            Rosie     Dog
# Akita                                             Kila     Dog
# Akita                                          Sachiko     Dog
# Akita                                             Okii     Dog
# Akita                                             Lana     Dog
# Alapaha Blue Blood Bulldog                        Oreo     Dog
# Alapaha Blue Blood Bulldog                        Lola     Dog
# Alaskan Husky                                   Casper     Dog
# ...                                                ...     ...
# Yorkshire Terrier                      Teddy Arthur Yu     Dog
# Yorkshire Terrier                                 Zeus     Dog
# Yorkshire Terrier                                 Desi     Dog
# Yorkshire Terrier                            Kylo Yuan     Dog
# Yorkshire Terrier                              Charger     Dog
# Yorkshire Terrier                               Gracie     Dog
# Yorkshire Terrier                                 Bear     Dog
# Yorkshire Terrier                         Duke of York     Dog
# Yorkshire Terrier                              Pimenta     Dog
# Yorkshire Terrier                               Calvin     Dog
# Yorkshire Terrier                               Murphy     Dog
# Yorkshire Terrier                                Bella     Dog
# Yorkshire Terrier                              Zsa Zsa     Dog
# Yorkshire Terrier                                 Loki     Dog
# Yorkshire Terrier                             Brewster     Dog
# Yorkshire Terrier                                Chula     Dog
# Yorkshire Terrier                                Elska     Dog
# Yorkshire Terrier                                Bogey     Dog
# Yorkshire Terrier                             Leonardo     Dog
# Yorkshire Terrier                                Kenji     Dog
# Yorkshire Terrier                              Gremlin     Dog
# Yorkshire Terrier                              Houston     Dog
# Yorkshire Terrier                                 Reba     Dog
# Yorkshire Terrier                               Spring     Dog
# Yorkshire Terrier                                 Jake     Dog
# Yorkshire Terrier                              Winston     Dog
# Yorkshire Terrier                                Buddy     Dog
# Yorkshire Terrier                                Dixie     Dog
# Yorkshire Terrier                                Henry     Dog
# Yorkshire Terrier                              Charlie     Dog
# Yorkshire Terrier                                Chloe     Dog
# Yorkshire Terrier                               Pepper     Dog
# Yorkshire Terrier                                Henry     Dog
# Yorkshire Terrier                                Buddy     Dog
# Yorkshire Terrier                               Apollo     Dog
# Yorkshire Terrier                               Lionel     Dog
# Yorkshire Terrier                              Charlie     Dog
# Yorkshire Terrier                                Molly     Dog
# Yorkshire Terrier                                Boone     Dog
# Yorkshire Terrier                            Pipsqueak     Dog
# Yorkshire Terrier                                Penny     Dog
# Yorkshire Terrier                                 KiKi     Dog
# Yorkshire Terrier                              Ponchik     Dog
# Yorkshire Terrier                               Casper     Dog
# Yorkshire Terrier                                Ernie     Dog
# Yorkshire Terrier                                  Zak     Dog
# Yorkshire Terrier                                Rocky     Dog
# Yorkshire Terrier                              Brownie     Dog
# Yorkshire Terrier                               Billie     Dog
# Yorkshire Terrier                                Molly     Dog
# Yorkshire Terrier                                 Thor     Dog
# Yorkshire Terrier                                Pippa     Dog
# Yorkshire Terrier                                 Hugo     Dog
# Yorkshire Terrier                                 Coco     Dog
# Yorkshire Terrier                                Basil     Dog
# Yorkshire Terrier                               Maddie     Dog
# Yorkshire Terrier                               Oliver     Dog
# Yorkshire Terrier                                  Ryu     Dog
# Yorkshire Terrier                                 Lola     Dog
# Yorkshire Terrier                               Oliver     Dog
# Yorkshire Terrier                                Kekko     Dog
# Yorkshire Terrier                                Marco     Dog
# Yorkshire Terrier                                 Zodi     Dog
# Yorkshire Terrier                                Dusty     Dog
# Yorkshire Terrier                                 Coco     Dog
# Yorkshire Terrier                              Chester     Dog
# Yorkshire Terrier                                Luigi     Dog
# Yorkshire Terrier                                Maisy     Dog
# Yorkshire Terrier                                Bella     Dog
# Yorkshire Terrier                                 Ruby     Dog
# Yorkshire Terrier                              Sparkie     Dog
# Yorkshire Terrier                                Maddy     Dog
# Yorkshire Terrier                                 Rico     Dog
# Yorkshire Terrier                              Scruffy     Dog
# Yorkshire Terrier                                 Dude     Dog
# Yorkshire Terrier                               Lizzie     Dog
# Yorkshire Terrier                                 Clos     Dog
# Yorkshire Terrier                                Sammy     Dog
# Yorkshire Terrier                               Cookie     Dog
# Yorkshire Terrier                                 Otis     Dog
# Yorkshire Terrier                                Bowie     Dog
# Yorkshire Terrier                               Millie     Dog
# Yorkshire Terrier                                Attie     Dog
# Yorkshire Terrier                                Elsie     Dog
# Yorkshire Terrier                                Colby     Dog
# Yorkshire Terrier                               Bailey     Dog
# Yorkshire Terrier                            Annabelle     Dog
# Yorkshire Terrier                               Bailee     Dog
# Yorkshire Terrier                               Scooby     Dog
# Yorkshire Terrier                              Bentley     Dog
# Yorkshire Terrier                                Scout     Dog
# Yorkshire Terrier                               Archie     Dog
# Yorkshire Terrier                               Boomer     Dog
# Yorkshire Terrier                               Buster     Dog
# Yorkshire Terrier                                  Ava     Dog
# Yorkshire Terrier                                Chewy     Dog
# Yorkshire Terrier                                Gilly     Dog
# Yorkshire Terrier                                  Gus     Dog
# Yorkshire Terrier                               Harley     Dog
# Yorkshire Terrier                                   Bo     Dog
#
#                                            Secondary Breed ZIP Code  Obedient  \
# Affenpinscher                                          NaN    98102      0.70
# Affenpinscher                                          NaN    98104      0.70
# Afghan Hound                                           NaN    98122      0.25
# Afghan Hound                                           NaN    98138      0.25
# Afghan Hound                                           NaN    98122      0.25
# Afghan Hound                                           NaN    98108      0.25
# Airedale Terrier                                       NaN    98103      0.70
# Airedale Terrier                                       NaN    98101      0.70
# Airedale Terrier                                       NaN    98125      0.70
# Airedale Terrier                          Golden Retriever    98133      0.70
# Airedale Terrier                                       NaN    98102      0.70
# Airedale Terrier                                       NaN    98109      0.70
# Airedale Terrier                                       NaN    98117      0.70
# Airedale Terrier                        Labrador Retriever    98107      0.70
# Airedale Terrier                                       NaN    98199      0.70
# Airedale Terrier                                       NaN    98112      0.70
# Airedale Terrier                                       NaN    98199      0.70
# Airedale Terrier                                       NaN    98116      0.70
# Airedale Terrier                                       NaN    98199      0.70
# Airedale Terrier                                       NaN    98116      0.70
# Airedale Terrier                                       NaN    98177      0.70
# Airedale Terrier                                       NaN    98122      0.70
# Airedale Terrier                                       NaN    98144      0.70
# Airedale Terrier                                       NaN    98126      0.70
# Airedale Terrier                                       NaN    98118      0.70
# Airedale Terrier                                       NaN    98115      0.70
# Airedale Terrier                             Pharaoh Hound    98117      0.70
# Airedale Terrier                                       NaN    98117      0.70
# Airedale Terrier                                       NaN    98115      0.70
# Airedale Terrier                            Siberian Husky    98118      0.70
# Airedale Terrier                                       NaN    98119      0.70
# Airedale Terrier                                     Hound    98115      0.70
# Airedale Terrier                           Irish Wolfhound    98106      0.70
# Airedale Terrier                           Standard Poodle    98116      0.70
# Airedale Terrier                                     Hound    98118      0.70
# Airedale Terrier                                       NaN    98177      0.70
# Airedale Terrier                                       NaN    98126      0.70
# Airedale Terrier                                       NaN    98118      0.70
# Airedale Terrier                                       NaN    98136      0.70
# Airedale Terrier                                       NaN    98103      0.70
# Airedale Terrier                                       NaN    98125      0.70
# Airedale Terrier                             Alaskan Husky    98112      0.70
# Airedale Terrier                        Labrador Retriever    98144      0.70
# Airedale Terrier                                       NaN    98103      0.70
# Airedale Terrier                                       NaN    98136      0.70
# Airedale Terrier                                       NaN    98116      0.70
# Airedale Terrier                                       NaN    98199      0.70
# Airedale Terrier                                       NaN    98115      0.70
# Airedale Terrier                                       NaN    98109      0.70
# Airedale Terrier                                       NaN    98105      0.70
# Airedale Terrier                                       NaN    98107      0.70
# Airedale Terrier                                       NaN    98117      0.70
# Airedale Terrier                                       NaN    98126      0.70
# Akbash                                                 NaN    98106       NaN
# Akbash                                                 NaN    98125       NaN
# Akbash                                                 NaN    98178       NaN
# Akita                                                  NaN    98117      0.50
# Akita                                                  NaN    98136      0.50
# Akita                                                  NaN    98126      0.50
# Akita                                      German Shepherd    98112      0.50
# Akita                                                  NaN    98103      0.50
# Akita                                                  NaN    98115      0.50
# Akita                                                Boxer    98115      0.50
# Akita                                                  NaN    98126      0.50
# Akita                                            Chow Chow    98103      0.50
# Akita                                                  NaN    98118      0.50
# Akita                       American Staffordshire Terrier    98144      0.50
# Akita                                                  NaN    98146      0.50
# Akita                                                  NaN    98118      0.50
# Akita                                              Terrier    98106      0.50
# Akita                                                  NaN    98199      0.50
# Akita                                        Alaskan Husky    98144      0.50
# Akita                                                  NaN    98133      0.50
# Akita                                                  NaN    98125      0.50
# Akita                                       Border Terrier    98112      0.50
# Akita                                                  NaN    98108      0.50
# Akita                                      German Shepherd    98126      0.50
# Akita                                Australian Cattle Dog    98108      0.50
# Akita                                                  NaN    98116      0.50
# Akita                                                  NaN    98199      0.50
# Akita                                                  NaN    98177      0.50
# Akita                                                Boxer    98103      0.50
# Akita                                      German Shepherd    98115      0.50
# Akita                                                  NaN    98115      0.50
# Akita                                   Labrador Retriever    98107      0.50
# Akita                                                  NaN    98108      0.50
# Akita                                                  NaN    98125      0.50
# Akita                                                  NaN    98126      0.50
# Akita                                            Chow Chow    98103      0.50
# Akita                                        Border Collie    98119      0.50
# Akita                                                Akita    98115      0.50
# Akita                                                  NaN    98133      0.50
# Akita                                                  NaN    98136      0.50
# Akita                                                  NaN    98144      0.50
# Akita                                             Shepherd    98119      0.50
# Akita                                                  NaN    98103      0.50
# Akita                                                  NaN    98126      0.50
# Alapaha Blue Blood Bulldog                             NaN    98118       NaN
# Alapaha Blue Blood Bulldog                             NaN    98199       NaN
# Alaskan Husky                                          NaN    98118       NaN
# ...                                                    ...      ...       ...
# Yorkshire Terrier                                      NaN    98103      0.70
# Yorkshire Terrier                                 Havanese    98125      0.70
# Yorkshire Terrier                                      NaN    98106      0.70
# Yorkshire Terrier                                      NaN    98107      0.70
# Yorkshire Terrier                            Japanese Chin    98106      0.70
# Yorkshire Terrier                                      NaN    98136      0.70
# Yorkshire Terrier                         Miniature Poodle    98107      0.70
# Yorkshire Terrier                                      NaN    98122      0.70
# Yorkshire Terrier                                      NaN    98115      0.70
# Yorkshire Terrier                                      NaN    98199      0.70
# Yorkshire Terrier                          Norwich Terrier    98122      0.70
# Yorkshire Terrier                            Silky Terrier    98109      0.70
# Yorkshire Terrier                                      NaN    98177      0.70
# Yorkshire Terrier                                      NaN    98118      0.70
# Yorkshire Terrier                                Chow Chow    98125      0.70
# Yorkshire Terrier                                 Shih Tzu    98101      0.70
# Yorkshire Terrier                         Miniature Poodle    98136      0.70
# Yorkshire Terrier                               Toy Poodle    98112      0.70
# Yorkshire Terrier                                      NaN    98125      0.70
# Yorkshire Terrier                                      NaN    98136      0.70
# Yorkshire Terrier                               Pomeranian    98117      0.70
# Yorkshire Terrier                                      NaN    98109      0.70
# Yorkshire Terrier                         Miniature Poodle    98103      0.70
# Yorkshire Terrier                                      NaN    98125      0.70
# Yorkshire Terrier                         Miniature Poodle    98117      0.70
# Yorkshire Terrier                                      NaN    98104      0.70
# Yorkshire Terrier                                      NaN    98125      0.70
# Yorkshire Terrier                                      NaN    98199      0.70
# Yorkshire Terrier                                      NaN    98103      0.70
# Yorkshire Terrier                         Miniature Poodle    98102      0.70
# Yorkshire Terrier                         Miniature Poodle    98103      0.70
# Yorkshire Terrier                               Toy Poodle    98116      0.70
# Yorkshire Terrier                                      NaN    98126      0.70
# Yorkshire Terrier                                      NaN    98116      0.70
# Yorkshire Terrier                                      NaN    98107      0.70
# Yorkshire Terrier                                      NaN    98107      0.70
# Yorkshire Terrier                                      NaN    98034      0.70
# Yorkshire Terrier                                  Maltese    98103      0.70
# Yorkshire Terrier                                      NaN    98102      0.70
# Yorkshire Terrier                                      NaN    98109      0.70
# Yorkshire Terrier                                Chihuahua    98119      0.70
# Yorkshire Terrier                                 Shih Tzu    98125      0.70
# Yorkshire Terrier                            Silky Terrier    98102      0.70
# Yorkshire Terrier                                      NaN    98125      0.70
# Yorkshire Terrier                         Miniature Poodle    98117      0.70
# Yorkshire Terrier                         Miniature Poodle    98122      0.70
# Yorkshire Terrier                                      NaN    98105      0.70
# Yorkshire Terrier                                 Shih Tzu    98118      0.70
# Yorkshire Terrier                                      NaN    98126      0.70
# Yorkshire Terrier                                      NaN    98144      0.70
# Yorkshire Terrier                                      NaN    98133      0.70
# Yorkshire Terrier                                      NaN    98126      0.70
# Yorkshire Terrier                                Schnauzer    98199      0.70
# Yorkshire Terrier                                      NaN    98106      0.70
# Yorkshire Terrier                                      NaN    98109      0.70
# Yorkshire Terrier                               Toy Poodle    98115      0.70
# Yorkshire Terrier                                      NaN    98115      0.70
# Yorkshire Terrier                                      NaN    98133      0.70
# Yorkshire Terrier                                      NaN    98199      0.70
# Yorkshire Terrier                                      NaN    98199      0.70
# Yorkshire Terrier                                      NaN    98177      0.70
# Yorkshire Terrier                                      NaN    98115      0.70
# Yorkshire Terrier                         Miniature Poodle    98103      0.70
# Yorkshire Terrier                                 Shih Tzu    98116      0.70
# Yorkshire Terrier                                      NaN    98126      0.70
# Yorkshire Terrier                         Miniature Poodle    98116      0.70
# Yorkshire Terrier                                      NaN    98117      0.70
# Yorkshire Terrier                                  Maltese    98121      0.70
# Yorkshire Terrier                                      NaN    98177      0.70
# Yorkshire Terrier                               Pomeranian    98101      0.70
# Yorkshire Terrier                                      NaN    98105      0.70
# Yorkshire Terrier                                      NaN    98199      0.70
# Yorkshire Terrier                                      NaN    98112      0.70
# Yorkshire Terrier                         Miniature Poodle    98118      0.70
# Yorkshire Terrier                                 Shih Tzu    98103      0.70
# Yorkshire Terrier                                      NaN    98136      0.70
# Yorkshire Terrier                                      NaN    98112      0.70
# Yorkshire Terrier                                      NaN    98103      0.70
# Yorkshire Terrier                                      NaN    98117      0.70
# Yorkshire Terrier                                  Maltese    98122      0.70
# Yorkshire Terrier                               Toy Poodle    98101      0.70
# Yorkshire Terrier                               Toy Poodle    98125      0.70
# Yorkshire Terrier                                      NaN    98117      0.70
# Yorkshire Terrier                                      NaN    98106      0.70
# Yorkshire Terrier                                      NaN    98116      0.70
# Yorkshire Terrier                                      NaN    98125      0.70
# Yorkshire Terrier                                      NaN    98144      0.70
# Yorkshire Terrier                                      NaN    98117      0.70
# Yorkshire Terrier                                  Maltese    98115      0.70
# Yorkshire Terrier                                      NaN    98103      0.70
# Yorkshire Terrier                                 Shih Tzu    98112      0.70
# Yorkshire Terrier                         Miniature Poodle    98144      0.70
# Yorkshire Terrier                                 Shih Tzu    98101      0.70
# Yorkshire Terrier                                      NaN    98126      0.70
# Yorkshire Terrier                                  Maltese    98117      0.70
# Yorkshire Terrier                                 Shih Tzu    98106      0.70
# Yorkshire Terrier                            Japanese Chin    98136      0.70
# Yorkshire Terrier                                      NaN    98104      0.70
# Yorkshire Terrier                                      NaN    98115      0.70
# Yorkshire Terrier                                 Shih Tzu    98116      0.70
#
#                             Calm  Trainable  Sociable  Bold
# Affenpinscher                NaN        NaN       NaN   NaN
# Affenpinscher                NaN        NaN       NaN   NaN
# Afghan Hound                 NaN        NaN       NaN   NaN
# Afghan Hound                 NaN        NaN       NaN   NaN
# Afghan Hound                 NaN        NaN       NaN   NaN
# Afghan Hound                 NaN        NaN       NaN   NaN
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Akbash                       NaN        NaN       NaN   NaN
# Akbash                       NaN        NaN       NaN   NaN
# Akbash                       NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Alapaha Blue Blood Bulldog   NaN        NaN       NaN   NaN
# Alapaha Blue Blood Bulldog   NaN        NaN       NaN   NaN
# Alaskan Husky                NaN        NaN       NaN   NaN
# ...                          ...        ...       ...   ...
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
#
# [18227 rows x 11 columns]

# %%
seattle_attrib.describe()
# Out:
#            Obedient          Calm     Trainable      Sociable          Bold
# count  14513.000000  12673.000000  12673.000000  12673.000000  12673.000000
# mean       0.670327      0.551882      0.597293      0.577961      0.598161
# std        0.266143      0.497321      0.331260      0.472030      0.457333
# min        0.250000      0.000000      0.000000      0.000000      0.000000
# 25%        0.500000      0.000000      0.500000      0.000000      0.000000
# 50%        0.700000      1.000000      0.500000      1.000000      1.000000
# 75%        0.950000      1.000000      1.000000      1.000000      1.000000
# max        0.950000      1.000000      1.000000      1.000000      1.000000

# %% [markdown]
# # Perform hypothesis tests for NYC boroughs

# %%
print('Alternative Hypothesis: dogs from Staten Island are bolder than other dogs in New York.')
non_staten = nyc_attrib[nyc_attrib['Borough'].isin(['Manhattan', 'Queens', 'Bronx', 'Brooklyn'])]
non_staten.dropna(inplace=True)
non_staten_bold = non_staten['Bold']
print('Non-Staten Island bold mean: ',non_staten_bold.mean())
staten = nyc_attrib[nyc_attrib['Borough'] == 'Staten Island']
staten.dropna(inplace=True)
staten_bold = staten['Bold']
print('Staten Island bold mean: ',staten_bold.mean())
print(stats.ttest_ind(staten_bold, non_staten_bold, equal_var = False))

print('\nAlternative Hypothesis: dogs from Staten Island are calmer than other dogs in New York.')
non_staten_calm = non_staten['Calm']
print('Non-Staten Island calm mean: ',non_staten_calm.mean())
staten_calm = staten['Calm']
print('Staten Island calm mean: ',staten_calm.mean())
print(stats.ttest_ind(staten_calm, non_staten_calm, equal_var = False))

print('\nAlternative Hypothesis: dogs from the Bronx and Queens are less trainable than other dogs in New York.')
non_bronxq = nyc_attrib[nyc_attrib['Borough'].isin(['Manhattan', 'Staten Island', 'Brooklyn'])]
non_bronxq.dropna(inplace=True)
non_bronxq_trainable = non_bronxq['Trainable']
print('Non-Bronx/Queens trainable mean: ',non_bronxq_trainable.mean())
bronxq = nyc_attrib[nyc_attrib['Borough'].isin(['Queens', 'Bronx'])]
bronxq.dropna(inplace=True)
bronxq_trainable = bronxq['Trainable']
print('Bronx/Queens trainable mean: ',bronxq_trainable.mean())
print(stats.ttest_ind(bronxq_trainable, non_bronxq_trainable, equal_var = False))

print('\nAlternative Hypothesis: dogs from the Bronx and Queens are less sociable than other dogs in New York.')
non_bronxq_sociable = non_bronxq['Sociable']
print('Non-Bronx/Queens sociable mean: ',non_bronxq_sociable.mean())
bronxq_sociable = bronxq['Sociable']
print('Bronx/Queens sociable mean: ',bronxq_sociable.mean())
print(stats.ttest_ind(non_bronxq_sociable, bronxq_sociable, equal_var = False))

print('\nNull Hypothesis: The average boldness of dogs in Brooklyn is the same as the average boldness for other New York dogs.')
print('Alternative Hypothesis: The average boldness of Brooklyn and other New York dogs is different.')
non_brooklyn = nyc_attrib[nyc_attrib['Borough'].isin(['Manhattan', 'Queens', 'Bronx', 'Staten Island'])]
non_brooklyn.dropna(inplace=True)
non_brooklyn_bold = non_brooklyn['Bold']
print('Non-Brooklyn bold mean: ',non_brooklyn_bold.mean())
brooklyn = nyc_attrib[nyc_attrib['Borough'] == 'Brooklyn']
brooklyn.dropna(inplace=True)
brooklyn_bold = staten['Bold']
print('Brooklyn bold mean: ',brooklyn_bold.mean())
print(stats.ttest_ind(brooklyn_bold, non_brooklyn_bold, equal_var = False))

print('\nNull Hypothesis: The average trainability of dogs in Brooklyn is the same as the average trainability for other New York dogs.')
print('Alternative Hypothesis: The average trainability of Brooklyn and other New York dogs is different.')
non_brooklyn_trainable = non_brooklyn['Trainable']
print('Non-Brooklyn trainable mean: ',non_brooklyn_trainable.mean())
brooklyn_trainable = brooklyn['Trainable']
print('Brooklyn trainable mean: ',brooklyn_trainable.mean())
print(stats.ttest_ind(non_brooklyn_trainable, brooklyn_trainable, equal_var = False))

print('\nNull Hypothesis: The average calmness of dogs in Brooklyn is the same as the average calmness for other New York dogs.')
print('Alternative Hypothesis: The average calmness of Brooklyn and other New York dogs is different.')
non_brooklyn_calm = non_brooklyn['Calm']
print('Non-Brooklyn calm mean: ',non_brooklyn_calm.mean())
brooklyn_calm = brooklyn['Calm']
print('Brooklyn calm mean: ',brooklyn_calm.mean())
print(stats.ttest_ind(non_brooklyn_calm, brooklyn_calm, equal_var = False))

print('\nNull Hypothesis: The average sociability of dogs in Brooklyn is the same as the average sociability for other New York dogs.')
print('Alternative Hypothesis: The average sociability of Brooklyn and other New York dogs is different.')
non_brooklyn_sociable = non_brooklyn['Sociable']
print('Non-Brooklyn sociable mean: ',non_brooklyn_sociable.mean())
brooklyn_sociable = brooklyn['Sociable']
print('Brooklyn sociable mean: ',brooklyn_sociable.mean())
print(stats.ttest_ind(non_brooklyn_sociable, brooklyn_sociable, equal_var = False))
# Out:
# Alternative Hypothesis: dogs from Staten Island are bolder than other dogs in New York.
# Non-Staten Island bold mean:  0.5814464313361202
# Staten Island bold mean:  0.6026777114236178
# Ttest_indResult(statistic=3.5363587630744457, pvalue=0.000408622819258394)
#
# Alternative Hypothesis: dogs from Staten Island are calmer than other dogs in New York.
# Non-Staten Island calm mean:  0.44211565257779845
# Staten Island calm mean:  0.48044692737430167
# Ttest_indResult(statistic=5.271707128263401, pvalue=1.3968278267828098e-07)
#
# Alternative Hypothesis: dogs from the Bronx and Queens are less trainable than other dogs in New York.
# Non-Bronx/Queens trainable mean:  0.47968762121486386
# Bronx/Queens trainable mean:  0.43733509234828494
# Ttest_indResult(statistic=-12.373471975924472, pvalue=4.319197929613958e-35)
#
# Alternative Hypothesis: dogs from the Bronx and Queens are less sociable than other dogs in New York.
# Non-Bronx/Queens sociable mean:  0.4729125184246593
# Bronx/Queens sociable mean:  0.41463280562884786
# Ttest_indResult(statistic=13.418861325479389, pvalue=5.881078650621579e-41)
#
# Null Hypothesis: The average boldness of dogs in Brooklyn is the same as the average boldness for other New York dogs.
# Alternative Hypothesis: The average boldness of Brooklyn and other New York dogs is different.
# Non-Brooklyn bold mean:  0.5904686480946614
# Brooklyn bold mean:  0.6026777114236178
# Ttest_indResult(statistic=2.0153830441949956, pvalue=0.04390575587099641)
#
# Null Hypothesis: The average trainability of dogs in Brooklyn is the same as the average trainability for other New York dogs.
# Alternative Hypothesis: The average trainability of Brooklyn and other New York dogs is different.
# Non-Brooklyn trainable mean:  0.4648048076027206
# Brooklyn trainable mean:  0.4702462134807264
# Ttest_indResult(statistic=-1.4599971103834517, pvalue=0.14430451367797537)
#
# Null Hypothesis: The average calmness of dogs in Brooklyn is the same as the average calmness for other New York dogs.
# Alternative Hypothesis: The average calmness of Brooklyn and other New York dogs is different.
# Non-Brooklyn calm mean:  0.4543464082735489
# Brooklyn calm mean:  0.4187064819467375
# Ttest_indResult(statistic=7.391820125767308, pvalue=1.4960597306069609e-13)
#
# Null Hypothesis: The average sociability of dogs in Brooklyn is the same as the average sociability for other New York dogs.
# Alternative Hypothesis: The average sociability of Brooklyn and other New York dogs is different.
# Non-Brooklyn sociable mean:  0.4631976148327588
# Brooklyn sociable mean:  0.4267461058071926
# Ttest_indResult(statistic=7.721934784086696, pvalue=1.1908284675337705e-14)

# %% [markdown]
# ## DOUBLE CHECK
#
# Note: due to Bonferroni correction, p-value must be lower than .00625.
#
# The null hypothesis is rejected in all cases, except:
# * Since the p-value is greater than 0.00625, we fail to reject the null hypothesis that dogs in Brooklyn are the same average trainability as dogs in other boroughs.
#
# The differences in the means is still relatively small. I will explore further using a Tukey test, which examines the differences of the means.

# %% [markdown]
# # Tukey tests - within NYC boroughs

# %%
for item in lst:
    print('\nAttribute: ',item)
    manhattan_item = pd.DataFrame(nyc_attrib[nyc_attrib['Borough'] == 'Manhattan'][item])
    manhattan_item['Borough'] = 'Manhattan'
    brooklyn_item = pd.DataFrame(nyc_attrib[nyc_attrib['Borough'] == 'Brooklyn'][item])
    brooklyn_item['Borough'] = 'Brooklyn'
    bronx_item = pd.DataFrame(nyc_attrib[nyc_attrib['Borough'] == 'Bronx'][item])
    bronx_item['Borough'] = 'Bronx'
    staten_item = pd.DataFrame(nyc_attrib[nyc_attrib['Borough'] == 'Staten Island'][item])
    staten_item['Borough'] = 'Staten Island'
    queens_item = pd.DataFrame(nyc_attrib[nyc_attrib['Borough'] == 'Queens'][item])
    queens_item['Borough'] = 'Queens'
    item_attrib = pd.concat([manhattan_item, brooklyn_item, bronx_item, staten_item, queens_item])
    item_attrib.dropna(inplace=True)
    item_attrib.reset_index(inplace=True)

    m = MultiComparison(item_attrib[item], item_attrib['Borough'])
    tukey = m.tukeyhsd()
    print(tukey.summary())
# Out:
# Attribute:  Trainable
#    Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =======================================================
#   group1      group2    meandiff  lower   upper  reject
# -------------------------------------------------------
#   Bronx      Brooklyn    0.0474   0.032   0.0628  True
#   Bronx     Manhattan    0.0635   0.0488  0.0782  True
#   Bronx       Queens     0.023    0.0071  0.0388  True
#   Bronx   Staten Island  0.0532   0.0342  0.0723  True
#  Brooklyn   Manhattan    0.0161   0.0047  0.0274  True
#  Brooklyn     Queens    -0.0245  -0.0373 -0.0116  True
#  Brooklyn Staten Island  0.0058  -0.0109  0.0225 False
# Manhattan     Queens    -0.0405  -0.0525 -0.0286  True
# Manhattan Staten Island -0.0103  -0.0263  0.0057 False
#   Queens  Staten Island  0.0303   0.0132  0.0474  True
# -------------------------------------------------------
#
# Attribute:  Obedient
#    Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =======================================================
#   group1      group2    meandiff  lower   upper  reject
# -------------------------------------------------------
#   Bronx      Brooklyn    0.014    0.0046  0.0234  True
#   Bronx     Manhattan    0.0258   0.0168  0.0347  True
#   Bronx       Queens     0.0154   0.0057  0.0251  True
#   Bronx   Staten Island  0.0386   0.027   0.0503  True
#  Brooklyn   Manhattan    0.0118   0.005   0.0186  True
#  Brooklyn     Queens     0.0014  -0.0063  0.0091 False
#  Brooklyn Staten Island  0.0246   0.0146  0.0347  True
# Manhattan     Queens    -0.0104  -0.0175 -0.0032  True
# Manhattan Staten Island  0.0129   0.0032  0.0225  True
#   Queens  Staten Island  0.0232   0.0129  0.0336  True
# -------------------------------------------------------
#
# Attribute:  Bold
#    Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =======================================================
#   group1      group2    meandiff  lower   upper  reject
# -------------------------------------------------------
#   Bronx      Brooklyn    0.0206   0.0039  0.0374  True
#   Bronx     Manhattan    0.067    0.0511  0.083   True
#   Bronx       Queens     0.0419   0.0247  0.0591  True
#   Bronx   Staten Island  0.0632   0.0425  0.0839  True
#  Brooklyn   Manhattan    0.0464   0.0341  0.0587  True
#  Brooklyn     Queens     0.0213   0.0073  0.0352  True
#  Brooklyn Staten Island  0.0426   0.0244  0.0607  True
# Manhattan     Queens    -0.0251  -0.0381 -0.0121  True
# Manhattan Staten Island -0.0039  -0.0212  0.0135 False
#   Queens  Staten Island  0.0213   0.0027  0.0398  True
# -------------------------------------------------------
#
# Attribute:  Calm
#    Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =======================================================
#   group1      group2    meandiff  lower   upper  reject
# -------------------------------------------------------
#   Bronx      Brooklyn    0.0594   0.0391  0.0796  True
#   Bronx     Manhattan    0.1315   0.1122  0.1508  True
#   Bronx       Queens     0.0769   0.056   0.0977  True
#   Bronx   Staten Island  0.1214   0.0962  0.1465  True
#  Brooklyn   Manhattan    0.0721   0.0572  0.0871  True
#  Brooklyn     Queens     0.0175   0.0006  0.0344  True
#  Brooklyn Staten Island  0.062    0.0401  0.0839  True
# Manhattan     Queens    -0.0547  -0.0704 -0.0389  True
# Manhattan Staten Island -0.0102  -0.0312  0.0109 False
#   Queens  Staten Island  0.0445   0.022   0.067   True
# -------------------------------------------------------
#
# Attribute:  Sociable
#    Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =======================================================
#   group1      group2    meandiff  lower   upper  reject
# -------------------------------------------------------
#   Bronx      Brooklyn    0.0652   0.0454  0.0849  True
#   Bronx     Manhattan    0.1418   0.123   0.1607  True
#   Bronx       Queens     0.0828   0.0624  0.1031  True
#   Bronx   Staten Island  0.1216   0.0971  0.1462  True
#  Brooklyn   Manhattan    0.0767   0.0621  0.0912  True
#  Brooklyn     Queens     0.0176   0.0011  0.0341  True
#  Brooklyn Staten Island  0.0565   0.0351  0.0779  True
# Manhattan     Queens    -0.0591  -0.0744 -0.0437  True
# Manhattan Staten Island -0.0202  -0.0407  0.0004 False
#   Queens  Staten Island  0.0389   0.0169  0.0608  True
# -------------------------------------------------------

# %% [markdown]
# ## Selected findings from Tukey tests
# There is a statistically significant relationship in most cases, but the mean difference is often small.
# * Manhattan dogs are more trainable than Bronx dogs.
# * Differences in the boldness among NYC dogs are minimal.
# * Differences in the obedience among NYC dogs are also minimal, though most pronounced between Staten Island and Manhattan vs. Bronx dogs.
# * Staten Island and Manhattan dogs are more sociable and calm than Bronx dogs.

# %% [markdown]
# # Tukey tests - between cities

# %%
seattle_attrib
# Out:
#                            License Issue Date License Number  \
# Affenpinscher                   April 18 2018         210596
# Affenpinscher                   March 21 2018         126404
# Afghan Hound                     July 23 2018        S119455
# Afghan Hound                      May 01 2018         141025
# Afghan Hound                     July 23 2018        S119454
# Afghan Hound                      May 31 2018         139371
# Airedale Terrier             December 13 2018         955156
# Airedale Terrier             November 06 2018         903738
# Airedale Terrier             November 14 2018         903865
# Airedale Terrier              October 31 2018        S122731
# Airedale Terrier             November 01 2018        8002383
# Airedale Terrier             December 22 2018        S138765
# Airedale Terrier             November 25 2018         831829
# Airedale Terrier             November 15 2018         901063
# Airedale Terrier              October 26 2018         829335
# Airedale Terrier             December 20 2018         960647
# Airedale Terrier             December 26 2018        8004137
# Airedale Terrier             November 26 2018         903207
# Airedale Terrier              October 27 2018        S113778
# Airedale Terrier             December 31 2018        8004256
# Airedale Terrier                March 20 2018         139797
# Airedale Terrier                 June 20 2018         142879
# Airedale Terrier               August 04 2018         581276
# Airedale Terrier             February 12 2018          80353
# Airedale Terrier                 July 31 2018        S116242
# Airedale Terrier                  May 22 2018        S128112
# Airedale Terrier               August 02 2018        S147625
# Airedale Terrier                  May 01 2018        S143363
# Airedale Terrier                April 10 2018         206213
# Airedale Terrier                April 17 2018        S142890
# Airedale Terrier            September 24 2018         355925
# Airedale Terrier                April 26 2018        S143259
# Airedale Terrier                 July 02 2018        S145513
# Airedale Terrier                  May 15 2018        S143752
# Airedale Terrier                April 19 2018        S127584
# Airedale Terrier                March 20 2018         139795
# Airedale Terrier            September 03 2018        S120963
# Airedale Terrier                 July 31 2018        S116243
# Airedale Terrier               August 25 2018        8000355
# Airedale Terrier                 July 13 2018         211845
# Airedale Terrier              October 17 2018        8001965
# Airedale Terrier              October 10 2018        S136964
# Airedale Terrier                 June 23 2018        S114871
# Airedale Terrier               August 30 2018        S115950
# Airedale Terrier              October 06 2018         831354
# Airedale Terrier              October 11 2018        S135838
# Airedale Terrier                April 13 2018        S105157
# Airedale Terrier              October 17 2018        S123677
# Airedale Terrier              October 12 2018        S137130
# Airedale Terrier                March 27 2018        S116150
# Airedale Terrier            September 05 2018        S120971
# Airedale Terrier                 July 26 2018         585247
# Airedale Terrier                 July 24 2018        S103581
# Akbash                       November 03 2018         835066
# Akbash                           June 05 2018        S144406
# Akbash                       February 20 2018        S140667
# Akita                        November 03 2018        S122687
# Akita                        December 02 2018         835072
# Akita                        November 05 2018        S124466
# Akita                        November 06 2018        S122407
# Akita                        November 05 2018        S135408
# Akita                        December 20 2018        S109090
# Akita                        November 06 2018         903832
# Akita                        December 24 2018        S152291
# Akita                         January 19 2018        S139655
# Akita                          August 29 2018        S145972
# Akita                            June 22 2018        S144364
# Akita                           April 03 2018         137235
# Akita                           April 24 2018        S111543
# Akita                            July 18 2018        S146601
# Akita                         January 06 2018        S139259
# Akita                        February 27 2018        S141040
# Akita                       September 30 2018        8001428
# Akita                       September 04 2018         726386
# Akita                           April 23 2018        S111944
# Akita                           March 29 2018         140873
# Akita                            July 31 2018        S147549
# Akita                           March 29 2018         215881
# Akita                          August 10 2018        S100452
# Akita                           March 23 2018        S127238
# Akita                       September 03 2018        S121245
# Akita                       September 24 2018        8001246
# Akita                            June 19 2018         215924
# Akita                         January 16 2018          24769
# Akita                       September 15 2018         583383
# Akita                           April 17 2018         212291
# Akita                        February 07 2018        S140407
# Akita                        February 09 2018        S111235
# Akita                            July 25 2018        S119982
# Akita                           April 03 2018         136686
# Akita                          August 14 2018        8000069
# Akita                       September 24 2018        S146685
# Akita                           April 18 2018        S128143
# Akita                           March 28 2018        S141847
# Akita                           March 20 2018         139361
# Akita                           March 20 2018         135456
# Akita                          August 08 2018        S120348
# Alapaha Blue Blood Bulldog   November 07 2018        S137136
# Alapaha Blue Blood Bulldog        May 24 2018        S141971
# Alaskan Husky                November 12 2018        S135451
# ...                                       ...            ...
# Yorkshire Terrier             January 06 2018        S139210
# Yorkshire Terrier           September 30 2018        S118582
# Yorkshire Terrier                 May 19 2018         282777
# Yorkshire Terrier                July 03 2018        S128719
# Yorkshire Terrier                July 30 2018         582967
# Yorkshire Terrier                July 24 2018         582840
# Yorkshire Terrier             October 07 2018         728103
# Yorkshire Terrier           September 23 2018         728616
# Yorkshire Terrier                July 23 2018          70905
# Yorkshire Terrier               April 23 2018        S106593
# Yorkshire Terrier                 May 01 2018        S111938
# Yorkshire Terrier              August 25 2018        S119484
# Yorkshire Terrier                June 14 2018         360327
# Yorkshire Terrier            February 09 2018          84234
# Yorkshire Terrier               March 28 2018         830856
# Yorkshire Terrier                July 24 2018        S119546
# Yorkshire Terrier               March 28 2018         140826
# Yorkshire Terrier           September 09 2018         729215
# Yorkshire Terrier            February 20 2018        S140719
# Yorkshire Terrier                 May 12 2018          81582
# Yorkshire Terrier             October 17 2018        S146735
# Yorkshire Terrier              August 24 2018        8000323
# Yorkshire Terrier           September 03 2018        8000589
# Yorkshire Terrier           September 19 2018         572642
# Yorkshire Terrier             October 10 2018        8001738
# Yorkshire Terrier               March 20 2018        S129485
# Yorkshire Terrier               April 29 2018          78373
# Yorkshire Terrier                July 01 2018         360414
# Yorkshire Terrier             October 08 2018         835363
# Yorkshire Terrier           September 07 2018         726878
# Yorkshire Terrier                July 16 2018        S118792
# Yorkshire Terrier             October 17 2018        8001939
# Yorkshire Terrier                June 12 2018         444763
# Yorkshire Terrier               April 19 2018         205168
# Yorkshire Terrier             January 25 2018        S139194
# Yorkshire Terrier               March 20 2018        S141615
# Yorkshire Terrier             October 13 2018        8001836
# Yorkshire Terrier              August 17 2018        8000159
# Yorkshire Terrier                July 05 2018          29485
# Yorkshire Terrier                July 21 2018        S119818
# Yorkshire Terrier             October 14 2018        8001847
# Yorkshire Terrier                June 14 2018        S130352
# Yorkshire Terrier               April 10 2018        S114275
# Yorkshire Terrier                July 18 2018        S146602
# Yorkshire Terrier               March 06 2018        S126186
# Yorkshire Terrier           September 04 2018         581559
# Yorkshire Terrier              August 04 2018         833915
# Yorkshire Terrier               March 13 2018         902456
# Yorkshire Terrier            February 08 2018          83009
# Yorkshire Terrier           September 07 2018         722414
# Yorkshire Terrier               April 13 2018        S113954
# Yorkshire Terrier                 May 10 2018         359965
# Yorkshire Terrier              August 17 2018        S102146
# Yorkshire Terrier               March 22 2018        S140942
# Yorkshire Terrier                July 21 2018         354786
# Yorkshire Terrier                June 27 2018        S145387
# Yorkshire Terrier            February 06 2018        S110253
# Yorkshire Terrier           September 11 2018        8000841
# Yorkshire Terrier                July 31 2018         445335
# Yorkshire Terrier                July 07 2018         435933
# Yorkshire Terrier                June 12 2018        S144613
# Yorkshire Terrier               April 11 2018        S142349
# Yorkshire Terrier              August 30 2018         357287
# Yorkshire Terrier           September 02 2018         729482
# Yorkshire Terrier               March 06 2018        S112401
# Yorkshire Terrier           September 08 2018         719965
# Yorkshire Terrier           September 30 2018        S146687
# Yorkshire Terrier              August 17 2018        8000161
# Yorkshire Terrier                June 27 2018        S112103
# Yorkshire Terrier               April 26 2018          71084
# Yorkshire Terrier                 May 15 2018          64361
# Yorkshire Terrier                July 01 2018         348621
# Yorkshire Terrier                June 19 2018        S144752
# Yorkshire Terrier            February 28 2018          15352
# Yorkshire Terrier                June 19 2018        S123925
# Yorkshire Terrier             January 30 2018        S140161
# Yorkshire Terrier                 May 22 2018        S143987
# Yorkshire Terrier                 May 08 2018         211719
# Yorkshire Terrier                June 20 2018         358057
# Yorkshire Terrier             October 11 2018        8001783
# Yorkshire Terrier               March 31 2018        S129294
# Yorkshire Terrier               April 10 2018        S142304
# Yorkshire Terrier               March 14 2018          23362
# Yorkshire Terrier                 May 16 2018        S143848
# Yorkshire Terrier             January 28 2018         961426
# Yorkshire Terrier           September 19 2018         572640
# Yorkshire Terrier           September 20 2018        8001126
# Yorkshire Terrier                July 17 2018         274171
# Yorkshire Terrier               March 20 2018         134304
# Yorkshire Terrier             January 16 2018          19548
# Yorkshire Terrier               March 23 2018        S127291
# Yorkshire Terrier                July 25 2018         439699
# Yorkshire Terrier             October 14 2018        S135874
# Yorkshire Terrier              August 03 2018        S129868
# Yorkshire Terrier            February 01 2018        S117431
# Yorkshire Terrier                June 04 2018        S115841
# Yorkshire Terrier              August 22 2018         729847
# Yorkshire Terrier           September 20 2018        S146385
# Yorkshire Terrier           September 26 2018        S134804
# Yorkshire Terrier             October 01 2018        8001462
#
#                                          Animal's Name Species  \
# Affenpinscher                                   Poirot     Dog
# Affenpinscher                                    Lucky     Dog
# Afghan Hound                                   Asteria     Dog
# Afghan Hound                                      Abby     Dog
# Afghan Hound                                     Atlas     Dog
# Afghan Hound                                      Luca     Dog
# Airedale Terrier                                  Otis     Dog
# Airedale Terrier                               Winston     Dog
# Airedale Terrier                                 Hogan     Dog
# Airedale Terrier                                 Daisy     Dog
# Airedale Terrier                                 Ellie     Dog
# Airedale Terrier                           Chimichurri     Dog
# Airedale Terrier                                 Daisy     Dog
# Airedale Terrier                                  Lucy     Dog
# Airedale Terrier                                  Nani     Dog
# Airedale Terrier                            Maddie Mae     Dog
# Airedale Terrier                                Palmer     Dog
# Airedale Terrier                                Maggie     Dog
# Airedale Terrier                                 Atlas     Dog
# Airedale Terrier                                Darwin     Dog
# Airedale Terrier                            Sophie May     Dog
# Airedale Terrier                                Oliver     Dog
# Airedale Terrier                                Harvey     Dog
# Airedale Terrier                                  Rory     Dog
# Airedale Terrier                                Bosley     Dog
# Airedale Terrier                                  Luna     Dog
# Airedale Terrier                                 Ellie     Dog
# Airedale Terrier                                   Max     Dog
# Airedale Terrier                                Nootka     Dog
# Airedale Terrier                                Violet     Dog
# Airedale Terrier                                 Darby     Dog
# Airedale Terrier                                 Wally     Dog
# Airedale Terrier                                  Dash     Dog
# Airedale Terrier                                Juneau     Dog
# Airedale Terrier                                Archer     Dog
# Airedale Terrier                                  Dave     Dog
# Airedale Terrier                                 Gizmo     Dog
# Airedale Terrier                                 Monty     Dog
# Airedale Terrier                         Charlie Brown     Dog
# Airedale Terrier                                  Tank     Dog
# Airedale Terrier                                RUPERT     Dog
# Airedale Terrier                                    Ri     Dog
# Airedale Terrier                               Wallace     Dog
# Airedale Terrier                                 Felix     Dog
# Airedale Terrier                               Chester     Dog
# Airedale Terrier                                 Ketch     Dog
# Airedale Terrier            Duchess Lacy van Notendale     Dog
# Airedale Terrier                     morgan4c27435168b     Dog
# Airedale Terrier                                Maisie     Dog
# Airedale Terrier                                 Artie     Dog
# Airedale Terrier                                Maggie     Dog
# Airedale Terrier                                Maggie     Dog
# Airedale Terrier                                  Hops     Dog
# Akbash                                           Sully     Dog
# Akbash                                            Yeti     Dog
# Akbash                                          Soappy     Dog
# Akita                                              Eva     Dog
# Akita                                           Dakota     Dog
# Akita                                             Toba     Dog
# Akita                                            Gizmo     Dog
# Akita                                             Bear     Dog
# Akita                                           Denali     Dog
# Akita                                             Sara     Dog
# Akita                                              Neo     Dog
# Akita                                            Himba     Dog
# Akita                                             Momo     Dog
# Akita                                             Desi     Dog
# Akita                                           Biggie     Dog
# Akita                                             Koda     Dog
# Akita                                      Rambo Buddy     Dog
# Akita                                               Lu     Dog
# Akita                                             Ella     Dog
# Akita                                            Sashi     Dog
# Akita                                           Wasabi     Dog
# Akita                                        Kira Kunz     Dog
# Akita                                             Abby     Dog
# Akita                                             Bear     Dog
# Akita                                             Koto     Dog
# Akita                                           Niseko     Dog
# Akita                                             Jack     Dog
# Akita                                             Kodi     Dog
# Akita                                              MAx     Dog
# Akita                                            Melba     Dog
# Akita                                      Smokey Bear     Dog
# Akita                                             Kita     Dog
# Akita                                              Aki     Dog
# Akita                                           Shinju     Dog
# Akita                                           Owsley     Dog
# Akita                                           Brodie     Dog
# Akita                                            Raven     Dog
# Akita                                               Oz     Dog
# Akita                                           Gunner     Dog
# Akita                                            Rosie     Dog
# Akita                                             Kila     Dog
# Akita                                          Sachiko     Dog
# Akita                                             Okii     Dog
# Akita                                             Lana     Dog
# Alapaha Blue Blood Bulldog                        Oreo     Dog
# Alapaha Blue Blood Bulldog                        Lola     Dog
# Alaskan Husky                                   Casper     Dog
# ...                                                ...     ...
# Yorkshire Terrier                      Teddy Arthur Yu     Dog
# Yorkshire Terrier                                 Zeus     Dog
# Yorkshire Terrier                                 Desi     Dog
# Yorkshire Terrier                            Kylo Yuan     Dog
# Yorkshire Terrier                              Charger     Dog
# Yorkshire Terrier                               Gracie     Dog
# Yorkshire Terrier                                 Bear     Dog
# Yorkshire Terrier                         Duke of York     Dog
# Yorkshire Terrier                              Pimenta     Dog
# Yorkshire Terrier                               Calvin     Dog
# Yorkshire Terrier                               Murphy     Dog
# Yorkshire Terrier                                Bella     Dog
# Yorkshire Terrier                              Zsa Zsa     Dog
# Yorkshire Terrier                                 Loki     Dog
# Yorkshire Terrier                             Brewster     Dog
# Yorkshire Terrier                                Chula     Dog
# Yorkshire Terrier                                Elska     Dog
# Yorkshire Terrier                                Bogey     Dog
# Yorkshire Terrier                             Leonardo     Dog
# Yorkshire Terrier                                Kenji     Dog
# Yorkshire Terrier                              Gremlin     Dog
# Yorkshire Terrier                              Houston     Dog
# Yorkshire Terrier                                 Reba     Dog
# Yorkshire Terrier                               Spring     Dog
# Yorkshire Terrier                                 Jake     Dog
# Yorkshire Terrier                              Winston     Dog
# Yorkshire Terrier                                Buddy     Dog
# Yorkshire Terrier                                Dixie     Dog
# Yorkshire Terrier                                Henry     Dog
# Yorkshire Terrier                              Charlie     Dog
# Yorkshire Terrier                                Chloe     Dog
# Yorkshire Terrier                               Pepper     Dog
# Yorkshire Terrier                                Henry     Dog
# Yorkshire Terrier                                Buddy     Dog
# Yorkshire Terrier                               Apollo     Dog
# Yorkshire Terrier                               Lionel     Dog
# Yorkshire Terrier                              Charlie     Dog
# Yorkshire Terrier                                Molly     Dog
# Yorkshire Terrier                                Boone     Dog
# Yorkshire Terrier                            Pipsqueak     Dog
# Yorkshire Terrier                                Penny     Dog
# Yorkshire Terrier                                 KiKi     Dog
# Yorkshire Terrier                              Ponchik     Dog
# Yorkshire Terrier                               Casper     Dog
# Yorkshire Terrier                                Ernie     Dog
# Yorkshire Terrier                                  Zak     Dog
# Yorkshire Terrier                                Rocky     Dog
# Yorkshire Terrier                              Brownie     Dog
# Yorkshire Terrier                               Billie     Dog
# Yorkshire Terrier                                Molly     Dog
# Yorkshire Terrier                                 Thor     Dog
# Yorkshire Terrier                                Pippa     Dog
# Yorkshire Terrier                                 Hugo     Dog
# Yorkshire Terrier                                 Coco     Dog
# Yorkshire Terrier                                Basil     Dog
# Yorkshire Terrier                               Maddie     Dog
# Yorkshire Terrier                               Oliver     Dog
# Yorkshire Terrier                                  Ryu     Dog
# Yorkshire Terrier                                 Lola     Dog
# Yorkshire Terrier                               Oliver     Dog
# Yorkshire Terrier                                Kekko     Dog
# Yorkshire Terrier                                Marco     Dog
# Yorkshire Terrier                                 Zodi     Dog
# Yorkshire Terrier                                Dusty     Dog
# Yorkshire Terrier                                 Coco     Dog
# Yorkshire Terrier                              Chester     Dog
# Yorkshire Terrier                                Luigi     Dog
# Yorkshire Terrier                                Maisy     Dog
# Yorkshire Terrier                                Bella     Dog
# Yorkshire Terrier                                 Ruby     Dog
# Yorkshire Terrier                              Sparkie     Dog
# Yorkshire Terrier                                Maddy     Dog
# Yorkshire Terrier                                 Rico     Dog
# Yorkshire Terrier                              Scruffy     Dog
# Yorkshire Terrier                                 Dude     Dog
# Yorkshire Terrier                               Lizzie     Dog
# Yorkshire Terrier                                 Clos     Dog
# Yorkshire Terrier                                Sammy     Dog
# Yorkshire Terrier                               Cookie     Dog
# Yorkshire Terrier                                 Otis     Dog
# Yorkshire Terrier                                Bowie     Dog
# Yorkshire Terrier                               Millie     Dog
# Yorkshire Terrier                                Attie     Dog
# Yorkshire Terrier                                Elsie     Dog
# Yorkshire Terrier                                Colby     Dog
# Yorkshire Terrier                               Bailey     Dog
# Yorkshire Terrier                            Annabelle     Dog
# Yorkshire Terrier                               Bailee     Dog
# Yorkshire Terrier                               Scooby     Dog
# Yorkshire Terrier                              Bentley     Dog
# Yorkshire Terrier                                Scout     Dog
# Yorkshire Terrier                               Archie     Dog
# Yorkshire Terrier                               Boomer     Dog
# Yorkshire Terrier                               Buster     Dog
# Yorkshire Terrier                                  Ava     Dog
# Yorkshire Terrier                                Chewy     Dog
# Yorkshire Terrier                                Gilly     Dog
# Yorkshire Terrier                                  Gus     Dog
# Yorkshire Terrier                               Harley     Dog
# Yorkshire Terrier                                   Bo     Dog
#
#                                            Secondary Breed ZIP Code  Obedient  \
# Affenpinscher                                          NaN    98102      0.70
# Affenpinscher                                          NaN    98104      0.70
# Afghan Hound                                           NaN    98122      0.25
# Afghan Hound                                           NaN    98138      0.25
# Afghan Hound                                           NaN    98122      0.25
# Afghan Hound                                           NaN    98108      0.25
# Airedale Terrier                                       NaN    98103      0.70
# Airedale Terrier                                       NaN    98101      0.70
# Airedale Terrier                                       NaN    98125      0.70
# Airedale Terrier                          Golden Retriever    98133      0.70
# Airedale Terrier                                       NaN    98102      0.70
# Airedale Terrier                                       NaN    98109      0.70
# Airedale Terrier                                       NaN    98117      0.70
# Airedale Terrier                        Labrador Retriever    98107      0.70
# Airedale Terrier                                       NaN    98199      0.70
# Airedale Terrier                                       NaN    98112      0.70
# Airedale Terrier                                       NaN    98199      0.70
# Airedale Terrier                                       NaN    98116      0.70
# Airedale Terrier                                       NaN    98199      0.70
# Airedale Terrier                                       NaN    98116      0.70
# Airedale Terrier                                       NaN    98177      0.70
# Airedale Terrier                                       NaN    98122      0.70
# Airedale Terrier                                       NaN    98144      0.70
# Airedale Terrier                                       NaN    98126      0.70
# Airedale Terrier                                       NaN    98118      0.70
# Airedale Terrier                                       NaN    98115      0.70
# Airedale Terrier                             Pharaoh Hound    98117      0.70
# Airedale Terrier                                       NaN    98117      0.70
# Airedale Terrier                                       NaN    98115      0.70
# Airedale Terrier                            Siberian Husky    98118      0.70
# Airedale Terrier                                       NaN    98119      0.70
# Airedale Terrier                                     Hound    98115      0.70
# Airedale Terrier                           Irish Wolfhound    98106      0.70
# Airedale Terrier                           Standard Poodle    98116      0.70
# Airedale Terrier                                     Hound    98118      0.70
# Airedale Terrier                                       NaN    98177      0.70
# Airedale Terrier                                       NaN    98126      0.70
# Airedale Terrier                                       NaN    98118      0.70
# Airedale Terrier                                       NaN    98136      0.70
# Airedale Terrier                                       NaN    98103      0.70
# Airedale Terrier                                       NaN    98125      0.70
# Airedale Terrier                             Alaskan Husky    98112      0.70
# Airedale Terrier                        Labrador Retriever    98144      0.70
# Airedale Terrier                                       NaN    98103      0.70
# Airedale Terrier                                       NaN    98136      0.70
# Airedale Terrier                                       NaN    98116      0.70
# Airedale Terrier                                       NaN    98199      0.70
# Airedale Terrier                                       NaN    98115      0.70
# Airedale Terrier                                       NaN    98109      0.70
# Airedale Terrier                                       NaN    98105      0.70
# Airedale Terrier                                       NaN    98107      0.70
# Airedale Terrier                                       NaN    98117      0.70
# Airedale Terrier                                       NaN    98126      0.70
# Akbash                                                 NaN    98106       NaN
# Akbash                                                 NaN    98125       NaN
# Akbash                                                 NaN    98178       NaN
# Akita                                                  NaN    98117      0.50
# Akita                                                  NaN    98136      0.50
# Akita                                                  NaN    98126      0.50
# Akita                                      German Shepherd    98112      0.50
# Akita                                                  NaN    98103      0.50
# Akita                                                  NaN    98115      0.50
# Akita                                                Boxer    98115      0.50
# Akita                                                  NaN    98126      0.50
# Akita                                            Chow Chow    98103      0.50
# Akita                                                  NaN    98118      0.50
# Akita                       American Staffordshire Terrier    98144      0.50
# Akita                                                  NaN    98146      0.50
# Akita                                                  NaN    98118      0.50
# Akita                                              Terrier    98106      0.50
# Akita                                                  NaN    98199      0.50
# Akita                                        Alaskan Husky    98144      0.50
# Akita                                                  NaN    98133      0.50
# Akita                                                  NaN    98125      0.50
# Akita                                       Border Terrier    98112      0.50
# Akita                                                  NaN    98108      0.50
# Akita                                      German Shepherd    98126      0.50
# Akita                                Australian Cattle Dog    98108      0.50
# Akita                                                  NaN    98116      0.50
# Akita                                                  NaN    98199      0.50
# Akita                                                  NaN    98177      0.50
# Akita                                                Boxer    98103      0.50
# Akita                                      German Shepherd    98115      0.50
# Akita                                                  NaN    98115      0.50
# Akita                                   Labrador Retriever    98107      0.50
# Akita                                                  NaN    98108      0.50
# Akita                                                  NaN    98125      0.50
# Akita                                                  NaN    98126      0.50
# Akita                                            Chow Chow    98103      0.50
# Akita                                        Border Collie    98119      0.50
# Akita                                                Akita    98115      0.50
# Akita                                                  NaN    98133      0.50
# Akita                                                  NaN    98136      0.50
# Akita                                                  NaN    98144      0.50
# Akita                                             Shepherd    98119      0.50
# Akita                                                  NaN    98103      0.50
# Akita                                                  NaN    98126      0.50
# Alapaha Blue Blood Bulldog                             NaN    98118       NaN
# Alapaha Blue Blood Bulldog                             NaN    98199       NaN
# Alaskan Husky                                          NaN    98118       NaN
# ...                                                    ...      ...       ...
# Yorkshire Terrier                                      NaN    98103      0.70
# Yorkshire Terrier                                 Havanese    98125      0.70
# Yorkshire Terrier                                      NaN    98106      0.70
# Yorkshire Terrier                                      NaN    98107      0.70
# Yorkshire Terrier                            Japanese Chin    98106      0.70
# Yorkshire Terrier                                      NaN    98136      0.70
# Yorkshire Terrier                         Miniature Poodle    98107      0.70
# Yorkshire Terrier                                      NaN    98122      0.70
# Yorkshire Terrier                                      NaN    98115      0.70
# Yorkshire Terrier                                      NaN    98199      0.70
# Yorkshire Terrier                          Norwich Terrier    98122      0.70
# Yorkshire Terrier                            Silky Terrier    98109      0.70
# Yorkshire Terrier                                      NaN    98177      0.70
# Yorkshire Terrier                                      NaN    98118      0.70
# Yorkshire Terrier                                Chow Chow    98125      0.70
# Yorkshire Terrier                                 Shih Tzu    98101      0.70
# Yorkshire Terrier                         Miniature Poodle    98136      0.70
# Yorkshire Terrier                               Toy Poodle    98112      0.70
# Yorkshire Terrier                                      NaN    98125      0.70
# Yorkshire Terrier                                      NaN    98136      0.70
# Yorkshire Terrier                               Pomeranian    98117      0.70
# Yorkshire Terrier                                      NaN    98109      0.70
# Yorkshire Terrier                         Miniature Poodle    98103      0.70
# Yorkshire Terrier                                      NaN    98125      0.70
# Yorkshire Terrier                         Miniature Poodle    98117      0.70
# Yorkshire Terrier                                      NaN    98104      0.70
# Yorkshire Terrier                                      NaN    98125      0.70
# Yorkshire Terrier                                      NaN    98199      0.70
# Yorkshire Terrier                                      NaN    98103      0.70
# Yorkshire Terrier                         Miniature Poodle    98102      0.70
# Yorkshire Terrier                         Miniature Poodle    98103      0.70
# Yorkshire Terrier                               Toy Poodle    98116      0.70
# Yorkshire Terrier                                      NaN    98126      0.70
# Yorkshire Terrier                                      NaN    98116      0.70
# Yorkshire Terrier                                      NaN    98107      0.70
# Yorkshire Terrier                                      NaN    98107      0.70
# Yorkshire Terrier                                      NaN    98034      0.70
# Yorkshire Terrier                                  Maltese    98103      0.70
# Yorkshire Terrier                                      NaN    98102      0.70
# Yorkshire Terrier                                      NaN    98109      0.70
# Yorkshire Terrier                                Chihuahua    98119      0.70
# Yorkshire Terrier                                 Shih Tzu    98125      0.70
# Yorkshire Terrier                            Silky Terrier    98102      0.70
# Yorkshire Terrier                                      NaN    98125      0.70
# Yorkshire Terrier                         Miniature Poodle    98117      0.70
# Yorkshire Terrier                         Miniature Poodle    98122      0.70
# Yorkshire Terrier                                      NaN    98105      0.70
# Yorkshire Terrier                                 Shih Tzu    98118      0.70
# Yorkshire Terrier                                      NaN    98126      0.70
# Yorkshire Terrier                                      NaN    98144      0.70
# Yorkshire Terrier                                      NaN    98133      0.70
# Yorkshire Terrier                                      NaN    98126      0.70
# Yorkshire Terrier                                Schnauzer    98199      0.70
# Yorkshire Terrier                                      NaN    98106      0.70
# Yorkshire Terrier                                      NaN    98109      0.70
# Yorkshire Terrier                               Toy Poodle    98115      0.70
# Yorkshire Terrier                                      NaN    98115      0.70
# Yorkshire Terrier                                      NaN    98133      0.70
# Yorkshire Terrier                                      NaN    98199      0.70
# Yorkshire Terrier                                      NaN    98199      0.70
# Yorkshire Terrier                                      NaN    98177      0.70
# Yorkshire Terrier                                      NaN    98115      0.70
# Yorkshire Terrier                         Miniature Poodle    98103      0.70
# Yorkshire Terrier                                 Shih Tzu    98116      0.70
# Yorkshire Terrier                                      NaN    98126      0.70
# Yorkshire Terrier                         Miniature Poodle    98116      0.70
# Yorkshire Terrier                                      NaN    98117      0.70
# Yorkshire Terrier                                  Maltese    98121      0.70
# Yorkshire Terrier                                      NaN    98177      0.70
# Yorkshire Terrier                               Pomeranian    98101      0.70
# Yorkshire Terrier                                      NaN    98105      0.70
# Yorkshire Terrier                                      NaN    98199      0.70
# Yorkshire Terrier                                      NaN    98112      0.70
# Yorkshire Terrier                         Miniature Poodle    98118      0.70
# Yorkshire Terrier                                 Shih Tzu    98103      0.70
# Yorkshire Terrier                                      NaN    98136      0.70
# Yorkshire Terrier                                      NaN    98112      0.70
# Yorkshire Terrier                                      NaN    98103      0.70
# Yorkshire Terrier                                      NaN    98117      0.70
# Yorkshire Terrier                                  Maltese    98122      0.70
# Yorkshire Terrier                               Toy Poodle    98101      0.70
# Yorkshire Terrier                               Toy Poodle    98125      0.70
# Yorkshire Terrier                                      NaN    98117      0.70
# Yorkshire Terrier                                      NaN    98106      0.70
# Yorkshire Terrier                                      NaN    98116      0.70
# Yorkshire Terrier                                      NaN    98125      0.70
# Yorkshire Terrier                                      NaN    98144      0.70
# Yorkshire Terrier                                      NaN    98117      0.70
# Yorkshire Terrier                                  Maltese    98115      0.70
# Yorkshire Terrier                                      NaN    98103      0.70
# Yorkshire Terrier                                 Shih Tzu    98112      0.70
# Yorkshire Terrier                         Miniature Poodle    98144      0.70
# Yorkshire Terrier                                 Shih Tzu    98101      0.70
# Yorkshire Terrier                                      NaN    98126      0.70
# Yorkshire Terrier                                  Maltese    98117      0.70
# Yorkshire Terrier                                 Shih Tzu    98106      0.70
# Yorkshire Terrier                            Japanese Chin    98136      0.70
# Yorkshire Terrier                                      NaN    98104      0.70
# Yorkshire Terrier                                      NaN    98115      0.70
# Yorkshire Terrier                                 Shih Tzu    98116      0.70
#
#                             Calm  Trainable  Sociable  Bold
# Affenpinscher                NaN        NaN       NaN   NaN
# Affenpinscher                NaN        NaN       NaN   NaN
# Afghan Hound                 NaN        NaN       NaN   NaN
# Afghan Hound                 NaN        NaN       NaN   NaN
# Afghan Hound                 NaN        NaN       NaN   NaN
# Afghan Hound                 NaN        NaN       NaN   NaN
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Airedale Terrier             1.0        0.5       1.0   1.0
# Akbash                       NaN        NaN       NaN   NaN
# Akbash                       NaN        NaN       NaN   NaN
# Akbash                       NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Akita                        NaN        NaN       NaN   NaN
# Alapaha Blue Blood Bulldog   NaN        NaN       NaN   NaN
# Alapaha Blue Blood Bulldog   NaN        NaN       NaN   NaN
# Alaskan Husky                NaN        NaN       NaN   NaN
# ...                          ...        ...       ...   ...
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
# Yorkshire Terrier            0.0        0.0       0.0   0.5
#
# [18227 rows x 11 columns]

# %%
adelaide_attrib = adelaide_registry.set_index('AnimalBreed').join(attrib, how='left')
edmonton_attrib = edmonton_registry.set_index('BREED').join(attrib, how='left')
# CHANGED THIS
# seattle_attrib = seattle_attrib.set_index('Primary Breed').join(attrib, how='left')

# %%
# Compare how trainable dogs are across different cities
for item in lst:
    print('\nAttribute: ',item)
    nyc_item = pd.DataFrame(nyc_attrib[item])
    nyc_item['Location'] = 'New York'
    seattle_item = pd.DataFrame(seattle_attrib[item])
    seattle_item['Location'] = 'Seattle'
    edmonton_item = pd.DataFrame(edmonton_attrib[item])
    edmonton_item['Location'] = 'Edmonton'
    adelaide_item = pd.DataFrame(adelaide_attrib[item])
    adelaide_item['Location'] = 'Adelaide'
    item_attrib = pd.concat([nyc_item, seattle_item, edmonton_item, adelaide_item])
    item_attrib.dropna(inplace=True)
    item_attrib.reset_index(inplace=True)

    m = MultiComparison(item_attrib[item], item_attrib['Location'])
    tukey = m.tukeyhsd()
    print(tukey.summary())
# Out:
# Attribute:  Trainable
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =================================================
#  group1   group2  meandiff  lower   upper  reject
# -------------------------------------------------
# Adelaide Edmonton  0.0543   0.0438  0.0648  True
# Adelaide New York -0.0566  -0.0668 -0.0464  True
# Adelaide Seattle   0.0753   0.0627  0.0878  True
# Edmonton New York -0.1109   -0.117 -0.1049  True
# Edmonton Seattle   0.021    0.0115  0.0305  True
# New York Seattle   0.1319   0.1227  0.141   True
# -------------------------------------------------
#
# Attribute:  Obedient
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =================================================
#  group1   group2  meandiff  lower   upper  reject
# -------------------------------------------------
# Adelaide Edmonton  0.0606   0.0535  0.0676  True
# Adelaide New York -0.0267  -0.0335 -0.0198  True
# Adelaide Seattle   0.0999   0.0914  0.1083  True
# Edmonton New York -0.0872  -0.0912 -0.0832  True
# Edmonton Seattle   0.0393   0.033   0.0457  True
# New York Seattle   0.1265   0.1204  0.1327  True
# -------------------------------------------------
#
# Attribute:  Bold
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ================================================
#  group1   group2  meandiff  lower  upper  reject
# ------------------------------------------------
# Adelaide Edmonton  0.0634   0.0508 0.0759  True
# Adelaide New York  0.0599   0.0478 0.072   True
# Adelaide Seattle   0.077    0.0621 0.0919  True
# Edmonton New York -0.0035  -0.0107 0.0038 False
# Edmonton Seattle   0.0137   0.0024 0.0249  True
# New York Seattle   0.0171   0.0063 0.028   True
# ------------------------------------------------
#
# Attribute:  Calm
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =================================================
#  group1   group2  meandiff  lower   upper  reject
# -------------------------------------------------
# Adelaide Edmonton  0.1089   0.0944  0.1233  True
# Adelaide New York  0.0321   0.0181  0.0461  True
# Adelaide Seattle   0.1374   0.1202  0.1547  True
# Edmonton New York -0.0767  -0.0851 -0.0684  True
# Edmonton Seattle   0.0286   0.0155  0.0416  True
# New York Seattle   0.1053   0.0927  0.1179  True
# -------------------------------------------------
#
# Attribute:  Sociable
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =================================================
#  group1   group2  meandiff  lower   upper  reject
# -------------------------------------------------
# Adelaide Edmonton  0.1109   0.0968  0.125   True
# Adelaide New York  0.0419   0.0282  0.0556  True
# Adelaide Seattle   0.166    0.1491  0.1828  True
# Edmonton New York  -0.069  -0.0772 -0.0609  True
# Edmonton Seattle   0.0551   0.0423  0.0678  True
# New York Seattle   0.1241   0.1118  0.1364  True
# -------------------------------------------------

# %% [markdown]
# # DOUBLE CHECK
# ## Selected findings from Tukey tests
#
# * Edmonton dogs and Seattle dogs are more trainable than New York dogs.
#
#
# * Seattle dogs are more obedient than New York dogs. Seattle dogs are more obedient than Adelaide dogs.
# * Adelaide dogs are less bold than Edmonton, New York, and Seattle dogs.
# * Adelaide dogs are less calm than Edmonton, New York, and Seattle dogs.
# * Adelaide dogs are less sociable than Edmonton, New York, and Seattle dogs.

# %% [markdown]
# # Summary by World Cities

# %%
# Show data on NYC, Seattle, Adelaide, and Edmonton
describe(nyc_attrib, 'NYC')
describe(seattle_attrib, 'Seattle')
describe(adelaide_attrib, 'Adelaide')
describe(edmonton_attrib, 'Edmonton')
print('-'*30)    

adelaide_mean = adelaide_attrib[lst].mean()
edmonton_mean = edmonton_attrib[lst].mean()
nyc_mean = nyc_attrib[lst].mean()
seattle_mean = seattle_attrib[lst].mean()

combined = pd.concat([nyc_mean,seattle_mean,edmonton_mean,adelaide_mean], axis=1)
combined.rename(columns={0:'New York', 1:'Seattle', 2:'Edmonton', 3:'Adelaide'}, inplace=True)
combined = combined.T
print(combined)

norm=True

print('\n'+'New York')
print(nyc_attrib.index.value_counts(normalize=norm).head(6))
print('\n'+'Seattle')
print(seattle_attrib.index.value_counts(normalize=norm).head(6))
print('\n'+'Edmonton')
print(edmonton_attrib.index.value_counts(normalize=norm).head(6))
print('\n'+'Adelaide')
print(adelaide_attrib.index.value_counts(normalize=norm).head(6))


plot_by_attrib(combined, lst, 'City')

for item in lst:
    plt.title(item+' Attribute by City')
    plt.bar(['New York','Seattle','Adelaide','Edmonton'], \
            [nyc_mean[item],seattle_mean[item], adelaide_mean[item], edmonton_mean[item]])
    plt.show()
# Out:
# NYC Mean
# Trainable    0.47
# Obedient     0.54
# Bold         0.58
# Calm         0.45
# Sociable     0.45
# dtype: float64
#
# NYC Standard Deviation
# Trainable    0.38
# Obedient     0.22
# Bold         0.46
# Calm         0.50
# Sociable     0.43
# dtype: float64
# Seattle Mean
# Trainable    0.60
# Obedient     0.67
# Bold         0.60
# Calm         0.55
# Sociable     0.58
# dtype: float64
#
# Seattle Standard Deviation
# Trainable    0.38
# Obedient     0.22
# Bold         0.46
# Calm         0.50
# Sociable     0.43
# dtype: float64
# Adelaide Mean
# Trainable    0.52
# Obedient     0.57
# Bold         0.52
# Calm         0.41
# Sociable     0.41
# dtype: float64
#
# Adelaide Standard Deviation
# Trainable    0.38
# Obedient     0.22
# Bold         0.46
# Calm         0.50
# Sociable     0.43
# dtype: float64
# Edmonton Mean
# Trainable    0.58
# Obedient     0.63
# Bold         0.58
# Calm         0.52
# Sociable     0.52
# dtype: float64
#
# Edmonton Standard Deviation
# Trainable    0.38
# Obedient     0.22
# Bold         0.46
# Calm         0.50
# Sociable     0.43
# dtype: float64
# ------------------------------
#           Trainable  Obedient      Bold      Calm  Sociable
# New York   0.465406  0.543779  0.581038  0.446582  0.453863
# Seattle    0.597293  0.670327  0.598161  0.551882  0.577961
# Edmonton   0.576334  0.631002  0.584502  0.523324  0.522898
# Adelaide   0.522014  0.570437  0.521140  0.414464  0.411995
#
# New York
# Yorkshire Terrier     0.073294
# Shih Tzu              0.067588
# Chihuahua             0.054931
# Maltese               0.040711
# Labrador Retriever    0.040098
# Pit Bull Mix          0.032425
# dtype: float64
#
# Seattle
# Labrador Retriever     0.139025
# Golden Retriever       0.061886
# Chihuahua              0.054205
# German Shepherd        0.030120
# Miniature Poodle       0.025896
# Australian Shepherd    0.025566
# dtype: float64
#
# Edmonton
# Labrador Retriever    0.091606
# Shih Tzu              0.080176
# German Shepherd       0.063006
# Chihuahua             0.044841
# Border Collie         0.040164
# Yorkshire Terrier     0.034863
# dtype: float64
#
# Adelaide
# Maltese                       0.108069
# Staffordshire Bull Terrier    0.062278
# Labrador Retriever            0.058608
# Jack Russell Terrier          0.056679
# Chihuahua                     0.043551
# Kelpie                        0.040876
# dtype: float64

# %%
x = np.arange(len(nyc_mean.index))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
fig.set_size_inches(10, 8)
rects1 = ax.bar(x - width/2, nyc_mean, width, label='New York')
rects1 = ax.bar(x + width/2, seattle_mean, width, label='Seattle')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores for New York and Seattle')
ax.set_xticks(x)
ax.set_xticklabels(nyc_mean.index)
ax.legend(loc='lower left', bbox_to_anchor= (1.05, .85), ncol=1, 
            borderaxespad=0, frameon=False)

plt.show()

# %% [markdown]
# ## Ancestral origin: looking at the UK and Ireland

# %%
ancestral = wiki[['Breed', 'Origin']]
ancestral_uk_ire = ancestral.copy()
ancestral_uk_ire.dropna(inplace=True)
ancestral_uk_ire = ancestral_uk_ire[ancestral_uk_ire['Origin'].isin(['England', 'Scotland', 'Wales', 'Ireland'])]
ancestral_uk_ire = ancestral_uk_ire.set_index('Breed').join(attrib, how='inner')
ancestral_uk_ire_grp = ancestral_uk_ire.groupby('Origin')
ancestral_uk_ire_mean = ancestral_uk_ire_grp.mean()
print('\nUK and Ireland Mean')
print(ancestral_uk_ire_grp.mean().round(decimals=2))
print('\nUK and Ireland Standard Deviation')
print(ancestral_uk_ire_grp.std().round(decimals=2))
print('\nUK and Ireland Count')

print(ancestral_uk_ire_grp.count())

# Plot the UK and Ireland data
# Remove Wales since it only has one dog for some of the data
ancestral_uk_ire_mean.drop('Wales', inplace=True)
plot_by_attrib(ancestral_uk_ire_mean, lst, 'UK and Irish Ancestry')

# Combining Scotland, Wales, and England as United Kingdom
ancestral['Origin'] = ancestral['Origin'].map(lambda x: 'United Kingdom' if x in {'England', 'Wales', 'Scotland'} else x)
ancestral_attrib = ancestral.set_index('Breed').join(attrib, how='inner')

print('UK breeds:')
wiki.fillna('', inplace=True)
print(wiki[wiki['Origin'].str.contains("United Kingdom")]['Breed'])

print('\nIreland breeds:')
print(wiki[wiki['Origin'].str.contains("Ireland")]['Breed'])
# Out:
# UK and Ireland Mean
#           Obedient  Calm  Trainable  Sociable  Bold
# Origin
# England       0.52  0.70        0.4      0.65   0.7
# Ireland       0.62  0.75        0.5      0.62   0.5
# Scotland      0.59  0.80        0.6      0.80   0.8
# Wales         0.59  0.00        1.0      0.00   0.0
#
# UK and Ireland Standard Deviation
#           Obedient  Calm  Trainable  Sociable  Bold
# Origin
# England       0.18  0.48       0.32      0.47  0.42
# Ireland       0.15  0.50       0.41      0.48  0.58
# Scotland      0.25  0.45       0.22      0.45  0.45
# Wales         0.24   NaN        NaN       NaN   NaN
#
# UK and Ireland Count
#           Obedient  Calm  Trainable  Sociable  Bold
# Origin
# England         19    10         10        10    10
# Ireland          6     4          4         4     4
# Scotland        10     5          5         5     5
# Wales            4     1          1         1     1
# UK breeds:
# 2                         Bloodhound
# 4                        Bullmastiff
# 10                       Otter Hound
# 39                Labrador Retriever
# 59                  Airedale Terrier
# 66                     Border Collie
# 75             Flat-Coated Retriever
# 106                   Border Terrier
# 111    Cavalier King Charles Spaniel
# 115              English Toy Spaniel
# 117                      Fox Terrier
# Name: Breed, dtype: object
#
# Ireland breeds:
# 8                 Irish Wolfhound
# 37                   Irish Setter
# 78                  Irish Terrier
# 79            Irish Water Spaniel
# 81             Kerry Blue Terrier
# 93    Soft-Coated Wheaten Terrier
# Name: Breed, dtype: object

# %% [markdown]
# ## Hypothesis testing

# %%
ancestral_attrib.dropna(inplace=True)
ancestral_attrib2 = splitDataFrameList(ancestral_attrib,'Origin', '/')
ancestral_attrib2['Origin'] = ancestral_attrib2['Origin'].map(lambda x: 'China' if x == 'Tibet (China)' else x)


print('Alternative Hypothesis: Dogs with ancestry from the UK are bolder than other dogs.')
ancestral_uk = ancestral_attrib2[ancestral_attrib2['Origin'] == 'United Kingdom']
ancestral_not_uk = ancestral_attrib2[~(ancestral_attrib2['Origin'] == 'United Kingdom')]
ancestral_uk_bold = ancestral_uk['Bold']
print('Ancestral UK Bold Mean:')
print(ancestral_uk_bold.mean())
ancestral_uk_bold.dropna(inplace=True)
ancestral_not_uk_bold = ancestral_not_uk['Bold']
ancestral_not_uk_bold.dropna(inplace=True)
print('Ancestral Non-UK Bold Mean:')
print(ancestral_not_uk_bold.mean())
print(stats.ttest_ind(ancestral_uk_bold, ancestral_not_uk_bold, equal_var = False))
# Out:
# Alternative Hypothesis: Dogs with ancestry from the UK are bolder than other dogs.
# Ancestral UK Bold Mean:
# 0.6818181818181818
# Ancestral Non-UK Bold Mean:
# 0.313953488372093
# Ttest_indResult(statistic=3.1133301873945967, pvalue=0.00331078574427337)

# %% [markdown]
# The p-value of 0.003 is less than 0.05, so we reject the null hypothesis. UK dogs are bolder than other dogs.

# %%
print('Null Hypothesis: The average obedience of UK dogs is the same as non-UK dogs.')
print('Alternative Hypothesis: The average obedience of UK dogs is different from non-UK dogs.')
ancestral_uk_obedient = ancestral_uk['Obedient']
ancestral_not_uk_obedient = ancestral_not_uk['Obedient']
print(stats.ttest_ind(ancestral_uk_obedient, ancestral_not_uk_obedient, equal_var = False))
# Out:
# Null Hypothesis: The average obedience of UK dogs is the same as non-UK dogs.
# Alternative Hypothesis: The average obedience of UK dogs is different from non-UK dogs.
# Ttest_indResult(statistic=0.3567621595443657, pvalue=0.7229897586669409)

# %% [markdown]
# The p-value of 0.822 is greater than 0.05, so we fail to reject the null hypothesis. UK dogs are of average obedience.

# %% [markdown]
# ## German dogs

# %%
print('German breeds:')
print(wiki[wiki['Origin'].str.contains("Germany")]['Breed'])

print('\nAlternative Hypothesis: Dogs with German ancestry are more obedient than other dogs.')
ancestral_ger = ancestral_attrib2[ancestral_attrib2['Origin'] == 'Germany']
ancestral_not_ger = ancestral_attrib2[~(ancestral_attrib2['Origin'] == 'Germany')]
ancestral_ger_obedient = ancestral_ger['Obedient']
print('Ancestral Germany Obedient Mean:')
print(ancestral_ger_obedient.mean())
ancestral_ger_obedient.dropna(inplace=True)
ancestral_not_ger_obedient = ancestral_not_ger['Obedient']
ancestral_not_ger_obedient.dropna(inplace=True)
print('Ancestral Non-Germany Obedient Mean:')
print(ancestral_not_ger_obedient.mean())
print(stats.ttest_ind(ancestral_ger_obedient, ancestral_not_ger_obedient, equal_var = False))
# Out:
# German breeds:
# 5                       Great Dane
# 11                      Rottweiler
# 22                           Boxer
# 27               Doberman Pinscher
# 30                 German Shepherd
# 31      German Shorthaired Pointer
# 32       German Wirehaired Pointer
# 33                 Giant Schnauzer
# 41                          Poodle
# 42                Miniature Poodle
# 43                      Toy Poodle
# 51                      Pomeranian
# 58                      Weimaraner
# 80                        Keeshond
# 86                     Plott Hound
# 95              Standard Schnauzer
# 99     Wirehaired Pointing Griffon
# 100                American Eskimo
# 113                      Dachshund
# 119                German Pinscher
# 138                  Affenpinscher
# Name: Breed, dtype: object
#
# Alternative Hypothesis: Dogs with German ancestry are more obedient than other dogs.
# Ancestral Germany Obedient Mean:
# 0.7541666666666668
# Ancestral Non-Germany Obedient Mean:
# 0.5726415094339623
# Ttest_indResult(statistic=2.7610725203292947, pvalue=0.012871713035894398)

# %% [markdown]
# The p-value of 0.009 is less than 0.05, so we reject the null hypothesis. German dogs are more obedient than other dogs.

# %%
print('Alternative Hypothesis: Dogs with German ancestry are less calm than other dogs.')
ancestral_ger_calm = ancestral_ger['Calm']
print('Ancestral Germany Calm Mean:')
print(ancestral_ger_calm.mean())
ancestral_ger_calm.dropna(inplace=True)
ancestral_not_ger_calm = ancestral_not_ger['Calm']
ancestral_not_ger_calm.dropna(inplace=True)
print('Ancestral Non-Germany Calm Mean:')
print(ancestral_not_ger_calm.mean())
print(stats.ttest_ind(ancestral_ger_calm, ancestral_not_ger_calm, equal_var = False))
# Out:
# Alternative Hypothesis: Dogs with German ancestry are less calm than other dogs.
# Ancestral Germany Calm Mean:
# 0.08333333333333333
# Ancestral Non-Germany Calm Mean:
# 0.5660377358490566
# Ttest_indResult(statistic=-4.468667004142404, pvalue=0.00011605889988818817)

# %% [markdown]
# The p-value of 0.0001 is less than 0.05, so we reject the null hypothesis. German dogs are less calm than other dogs.
